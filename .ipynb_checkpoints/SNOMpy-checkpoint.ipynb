# %%
pip install snompy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement snompy (from versions: none)
# ERROR: No matching distribution found for snompy

# %%
pip install matplotlib scipy
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np

import snompy

# Set some experimental parameters for an AFM approach curve
z_tip = np.linspace(0, 60e-9, 512)  # Define an approach curve
A_tip = 20e-9  # AFM tip tapping amplitude
harmonics = np.array([2, 3, 4])  # Harmonics for demodulation
eps_Si = 11.7  # Si permitivitty in the mid-infrared
sample = snompy.bulk_sample(eps_sub=eps_Si)  # Sample object

# Calculate the effective polarizability using FDM and PDM
alpha_eff_fdm = snompy.fdm.eff_pol_n(
    sample=sample,
    A_tip=A_tip,
    n=harmonics,
    z_tip=z_tip[:, np.newaxis],  # newaxis added for array broadcasting
)
alpha_eff_pdm = snompy.pdm.eff_pol_n(
    sample=sample,
    A_tip=A_tip,
    n=harmonics,
    z_tip=z_tip[:, np.newaxis],  # newaxis added for array broadcasting
)

# Normalize to value at z_tip = 0
alpha_eff_fdm /= alpha_eff_fdm[0]
alpha_eff_pdm /= alpha_eff_pdm[0]

# Plot output
fig, ax = plt.subplots()
z_nm = z_tip * 1e9  # For neater plotting
ax.plot(z_nm, np.abs(alpha_eff_fdm), label=[f"FDM: $n = ${n}" for n in harmonics])
ax.plot(
    z_nm, np.abs(alpha_eff_pdm), label=[f"PDM: $n = ${n}" for n in harmonics], ls="--"
)
ax.set(
    xlabel=r"$z_{tip}$ / nm",
    ylabel=r"$|\alpha_{eff, n}|$ / a.u.",
    xlim=(z_nm.min(), z_nm.max()),
)
ax.legend(ncol=2)
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 4 import snompy
#       6 # Set some experimental parameters for an AFM approach curve
#       7 z_tip = np.linspace(0, 60e-9, 512)  # Define an approach curve
#
# ModuleNotFoundError: No module named 'snompy'

# %%
import numpy as np
import matplotlib.pyplot as plt
# Assuming snompy is the control library provided by the instrument vendor
# import snompy 

class MockSNOM:
    """Mock class to simulate nano-FTIR signal acquisition."""
    def __init__(self):
        print("Connecting to nano-FTIR instrument...")
        self.connected = True

    def set_sample(self, sample_name):
        print(f"Sample set to: {sample_name}")

    def set_scan_parameters(self, start_wavenumber, end_wavenumber, resolution):
        self.wn_start = start_wavenumber
        self.wn_end = end_wavenumber
        self.resolution = resolution
        self.wns = np.linspace(start_wavenumber, end_wavenumber, resolution)

    def acquire_signal(self):
        """Simulated FTIR signal of Si3N4 on Si (mock spectrum)."""
        # Simulated response: Si3N4 absorption near 850 cm⁻¹ and 1100 cm⁻¹
        signal = (
            np.exp(-((self.wns - 850) ** 2) / (2 * 10**2)) +
            0.5 * np.exp(-((self.wns - 1100) ** 2) / (2 * 20**2)) +
            0.1 * np.random.randn(len(self.wns))
        )
        return self.wns, signal

    def disconnect(self):
        print("Disconnecting...")
        self.connected = False


def main():
    # Initialize instrument
    instrument = MockSNOM()
    instrument.set_sample("Si3N4 on Si")

    # Set FTIR scan range (e.g., mid-IR: 700–1500 cm⁻¹)
    instrument.set_scan_parameters(start_wavenumber=700, end_wavenumber=1500, resolution=800)

    # Acquire signal
    wavenumbers, signal = instrument.acquire_signal()

    # Plot the result
    plt.figure(figsize=(8, 5))
    plt.plot(wavenumbers, signal, label="nano-FTIR Signal")
    plt.xlabel("Wavenumber (cm⁻¹)")
    plt.ylabel("Amplitude (a.u.)")
    plt.title("nano-FTIR of Si₃N₄ on Si")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    instrument.disconnect()


if __name__ == "__main__":
    main()
# Out:
# Connecting to nano-FTIR instrument...
# Sample set to: Si3N4 on Si
# Disconnecting...

# %%
import numpy as np
import matplotlib.pyplot as plt
import snompy

# Define the infrared frequency range (in cm⁻¹)
frequencies = np.linspace(800, 1800, 300)  # IR range

# Convert to angular frequency in rad/s
omega = 2 * np.pi * snompy.util.wavenumber_to_omega(frequencies)

# Tip properties
tip_radius = 30e-9  # 30 nm radius
A_tip = 20e-9       # AFM tapping amplitude
z_tip = np.linspace(0, 60e-9, 512)

# Define material properties for graphite (approximate complex dielectric constant)
# ε = ε' + iε'' = 10 + 4j (valid for IR range)
graphite_eps = 10 + 4j

# Create the sample
sample = snompy.layer_stack([
    snompy.material(graphite_eps),     # Graphite layer (semi-infinite)
])

# Define the tip-sample interaction model
model = snompy.model(
    z_tip=z_tip,
    A=A_tip,
    R=tip_radius,
    sample=sample
)

# Compute effective polarizability
alpha_eff = model.alpha(omega)

# Get the demodulated near-field signal at 2nd harmonic (s₂)
s2 = model.demodulate(alpha_eff, harmonic=2)

# Plot the spectrum
plt.figure(figsize=(8, 4))
plt.plot(frequencies, np.abs(s2), label='|s₂| (graphite)')
plt.xlabel('Wavenumber (cm⁻¹)')
plt.ylabel('Near-field signal (a.u.)')
plt.title('nano-FTIR Spectrum of Graphite (2nd Harmonic)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 9
#       6 frequencies = np.linspace(800, 1800, 300)  # IR range
#       8 # Convert to angular frequency in rad/s
# ----> 9 omega = 2 * np.pi * snompy.util.wavenumber_to_omega(frequencies)
#      11 # Tip properties
#      12 tip_radius = 30e-9  # 30 nm radius
#
# AttributeError: module 'snompy' has no attribute 'util'

# %%
import numpy as np
import matplotlib.pyplot as plt
import snompy

# Define the IR wavenumber range (in cm⁻¹)
frequencies = np.linspace(800, 1800, 300)  # Wavenumber range in cm⁻¹

# Speed of light in cm/s
c_cm_per_s = 2.998e10

# Convert wavenumber (cm⁻¹) to angular frequency (rad/s)
omega = 2 * np.pi * c_cm_per_s * frequencies

# Tip properties
tip_radius = 30e-9  # 30 nm radius
A_tip = 20e-9       # AFM tapping amplitude
z_tip = np.linspace(0, 60e-9, 512)

# Define graphite dielectric constant (approximate)
graphite_eps = 10 + 4j

# Create sample stack: semi-infinite graphite
sample = snompy.layer_stack([
    snompy.material(graphite_eps),
])

# Create the near-field model
model = snompy.model(
    z_tip=z_tip,
    A=A_tip,
    R=tip_radius,
    sample=sample
)

# Compute effective polarizability
alpha_eff = model.alpha(omega)

# Demodulate at 2nd harmonic
s2 = model.demodulate(alpha_eff, harmonic=2)

# Plot the near-field signal
plt.figure(figsize=(8, 4))
plt.plot(frequencies, np.abs(s2), label='|s₂| (graphite)')
plt.xlabel('Wavenumber (cm⁻¹)')
plt.ylabel('Near-field signal (a.u.)')
plt.title('nano-FTIR Spectrum of Graphite (2nd Harmonic)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 23
#      20 graphite_eps = 10 + 4j
#      22 # Create sample stack: semi-infinite graphite
# ---> 23 sample = snompy.layer_stack([
#      24     snompy.material(graphite_eps),
#      25 ])
#      27 # Create the near-field model
#      28 model = snompy.model(
#      29     z_tip=z_tip,
#      30     A=A_tip,
#      31     R=tip_radius,
#      32     sample=sample
#      33 )
#
# AttributeError: module 'snompy' has no attribute 'layer_stack'

# %%
import numpy as np
import matplotlib.pyplot as plt
import snompy

# Wavenumber range (in cm⁻¹)
frequencies = np.linspace(800, 1800, 300)

# Convert wavenumber to angular frequency (rad/s)
c_cm_per_s = 2.998e10  # Speed of light in cm/s
omega = 2 * np.pi * c_cm_per_s * frequencies

# Tip properties
tip_radius = 30e-9      # Tip radius (m)
A_tip = 20e-9           # Tapping amplitude (m)
z_tip = np.linspace(0, 60e-9, 512)

# Graphite dielectric function (approximate)
graphite_eps = 10 + 4j

# Create sample (semi-infinite graphite)
sample = snompy.Sample([
    snompy.Material(graphite_eps)
])

# Create the model
model = snompy.Model(
    z_tip=z_tip,
    A=A_tip,
    R=tip_radius,
    sample=sample
)

# Compute effective polarizability
alpha_eff = model.alpha(omega)

# Demodulate at 2nd harmonic
s2 = model.demodulate(alpha_eff, harmonic=2)

# Plot the result
plt.figure(figsize=(8, 4))
plt.plot(frequencies, np.abs(s2), label='|s₂| (graphite)')
plt.xlabel('Wavenumber (cm⁻¹)')
plt.ylabel('Near-field signal (a.u.)')
plt.title('nano-FTIR Spectrum of Graphite (2nd Harmonic)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 22
#      18 graphite_eps = 10 + 4j
#      20 # Create sample (semi-infinite graphite)
#      21 sample = snompy.Sample([
# ---> 22     snompy.Material(graphite_eps)
#      23 ])
#      25 # Create the model
#      26 model = snompy.Model(
#      27     z_tip=z_tip,
#      28     A=A_tip,
#      29     R=tip_radius,
#      30     sample=sample
#      31 )
#
# AttributeError: module 'snompy' has no attribute 'Material'

# %%
import numpy as np
import matplotlib.pyplot as plt
import snompy

# Define IR wavenumber range (in cm⁻¹)
frequencies = np.linspace(800, 1800, 300)

# Convert to angular frequency (rad/s)
c_cm_per_s = 2.998e10  # Speed of light in cm/s
omega = 2 * np.pi * c_cm_per_s * frequencies

# Tip geometry
tip_radius = 30e-9     # 30 nm
A_tip = 20e-9          # Tapping amplitude
z_tip = np.linspace(0, 60e-9, 512)

# Graphite dielectric constant (approximate, isotropic)
graphite_eps = 10 + 4j

# ✅ Create a semi-infinite graphite sample
sample = snompy.sample([
    snompy.material(graphite_eps)
])

# Define the tip-sample interaction model
model = snompy.model(
    z_tip=z_tip,
    A=A_tip,
    R=tip_radius,
    sample=sample
)

# Compute effective polarizability
alpha_eff = model.alpha(omega)

# Extract 2nd harmonic near-field signal
s2 = model.demodulate(alpha_eff, harmonic=2)

# Plot near-field response
plt.figure(figsize=(8, 4))
plt.plot(frequencies, np.abs(s2), label='|s₂| (graphite)')
plt.xlabel('Wavenumber (cm⁻¹)')
plt.ylabel('Near-field signal (a.u.)')
plt.title('nano-FTIR of Graphite – 2nd Harmonic')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 22
#      18 graphite_eps = 10 + 4j
#      20 # ✅ Create a semi-infinite graphite sample
#      21 sample = snompy.sample([
# ---> 22     snompy.material(graphite_eps)
#      23 ])
#      25 # Define the tip-sample interaction model
#      26 model = snompy.model(
#      27     z_tip=z_tip,
#      28     A=A_tip,
#      29     R=tip_radius,
#      30     sample=sample
#      31 )
#
# AttributeError: module 'snompy' has no attribute 'material'

# %%
import numpy as np
import matplotlib.pyplot as plt
import snompy

# Define IR wavenumber range (in cm⁻¹)
frequencies = np.linspace(800, 1800, 300)

# Convert to angular frequency (rad/s)
c_cm_per_s = 2.998e10  # speed of light in cm/s
omega = 2 * np.pi * c_cm_per_s * frequencies  # rad/s

# Tip geometry
tip_radius = 30e-9     # Tip radius in meters
A_tip = 20e-9          # Tapping amplitude in meters
z_tip = np.linspace(0, 60e-9, 512)

# Graphite dielectric function (approximate, isotropic)
# Create array of same length as omega
eps_graphite = (10 + 4j) * np.ones_like(omega)

# Build sample as a list of layers — only one semi-infinite graphite layer
sample = [eps_graphite]  # This is directly the permittivity vs frequency

# Create the model
model = snompy.model(
    z_tip=z_tip,
    A=A_tip,
    R=tip_radius,
    sample=sample
)

# Compute effective polarizability
alpha_eff = model.alpha(omega)

# Demodulate at 2nd harmonic
s2 = model.demodulate(alpha_eff, harmonic=2)

# Plot near-field response
plt.figure(figsize=(8, 4))
plt.plot(frequencies, np.abs(s2), label='|s₂| (graphite)')
plt.xlabel('Wavenumber (cm⁻¹)')
plt.ylabel('Near-field signal (a.u.)')
plt.title('nano-FTIR of Graphite – 2nd Harmonic')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 25
#      22 sample = [eps_graphite]  # This is directly the permittivity vs frequency
#      24 # Create the model
# ---> 25 model = snompy.model(
#      26     z_tip=z_tip,
#      27     A=A_tip,
#      28     R=tip_radius,
#      29     sample=sample
#      30 )
#      32 # Compute effective polarizability
#      33 alpha_eff = model.alpha(omega)
#
# AttributeError: module 'snompy' has no attribute 'model'

# %%
import numpy as np
import matplotlib.pyplot as plt
import snompy

# Define IR wavenumber range (in cm⁻¹)
frequencies = np.linspace(800, 1800, 300)

# Convert to angular frequency (rad/s)
c_cm_per_s = 2.998e10  # speed of light in cm/s
omega = 2 * np.pi * c_cm_per_s * frequencies

# Tip parameters
tip_radius = 30e-9     # Tip radius (m)
A_tip = 20e-9          # Tapping amplitude (m)
z_tip = np.linspace(0, 60e-9, 512)

# Define graphite permittivity (assumed constant over freq)
eps_graphite = (10 + 4j) * np.ones_like(omega)

# Define sample as a list of layers (semi-infinite graphite)
sample = [eps_graphite]

# ✅ Use the Model class (capital 'M')
model = snompy.Model(
    z_tip=z_tip,
    A=A_tip,
    R=tip_radius,
    sample=sample
)

# Compute effective polarizability
alpha_eff = model.alpha(omega)

# Extract the demodulated signal (e.g., 2nd harmonic)
s2 = model.demodulate(alpha_eff, harmonic=2)

# Plot the result
plt.figure(figsize=(8, 4))
plt.plot(frequencies, np.abs(s2), label='|s₂| (graphite)')
plt.xlabel('Wavenumber (cm⁻¹)')
plt.ylabel('Near-field signal (a.u.)')
plt.title('nano-FTIR of Graphite – 2nd Harmonic')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 24
#      21 sample = [eps_graphite]
#      23 # ✅ Use the Model class (capital 'M')
# ---> 24 model = snompy.Model(
#      25     z_tip=z_tip,
#      26     A=A_tip,
#      27     R=tip_radius,
#      28     sample=sample
#      29 )
#      31 # Compute effective polarizability
#      32 alpha_eff = model.alpha(omega)
#
# AttributeError: module 'snompy' has no attribute 'Model'

# %%
import numpy as np
import matplotlib.pyplot as plt
import snompy

# Define wavenumber range (cm⁻¹)
frequencies = np.linspace(800, 1800, 300)

# Convert to angular frequency (rad/s)
c_cm_per_s = 2.998e10
omega = 2 * np.pi * c_cm_per_s * frequencies

# Tip parameters
tip_radius = 30e-9
A_tip = 20e-9
z_tip = np.linspace(0, 60e-9, 512)

# Constant permittivity of graphite (approximate)
eps_graphite = (10 + 4j) * np.ones_like(omega)

# ✅ Create model using the older functional API
model = snompy.tip_sample_model(
    z_tip=z_tip,
    A=A_tip,
    R=tip_radius,
    sample=[eps_graphite]  # semi-infinite graphite
)

# Compute effective polarizability
alpha_eff = model.alpha(omega)

# Demodulate to get near-field signal (2nd harmonic)
s2 = model.demodulate(alpha_eff, harmonic=2)

# Plot the result
plt.figure(figsize=(8, 4))
plt.plot(frequencies, np.abs(s2), label='|s₂| (graphite)')
plt.xlabel('Wavenumber (cm⁻¹)')
plt.ylabel('Near-field signal (a.u.)')
plt.title('nano-FTIR of Graphite – 2nd Harmonic')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 21
#      18 eps_graphite = (10 + 4j) * np.ones_like(omega)
#      20 # ✅ Create model using the older functional API
# ---> 21 model = snompy.tip_sample_model(
#      22     z_tip=z_tip,
#      23     A=A_tip,
#      24     R=tip_radius,
#      25     sample=[eps_graphite]  # semi-infinite graphite
#      26 )
#      28 # Compute effective polarizability
#      29 alpha_eff = model.alpha(omega)
#
# AttributeError: module 'snompy' has no attribute 'tip_sample_model'

# %%
import numpy as np
import matplotlib.pyplot as plt
import snompy

# Define wavenumber range in cm⁻¹
frequencies = np.linspace(800, 1800, 300)

# Convert to angular frequency (rad/s)
c_cm_per_s = 2.998e10
omega = 2 * np.pi * c_cm_per_s * frequencies

# Tip properties
tip_radius = 30e-9      # meters
A_tip = 20e-9           # meters
z_tip = np.linspace(0, 60e-9, 512)

# Graphite dielectric constant (approximate, constant)
eps_graphite = (10 + 4j) * np.ones_like(omega)

# ✅ Create model using the class directly
model = snompy.TipSampleModel(
    z_tip=z_tip,
    A=A_tip,
    R=tip_radius,
    sample=[eps_graphite]
)

# Compute effective polarizability
alpha_eff = model.alpha(omega)

# Demodulate at 2nd harmonic
s2 = model.demodulate(alpha_eff, harmonic=2)

# Plot near-field signal
plt.figure(figsize=(8, 4))
plt.plot(frequencies, np.abs(s2), label='|s₂| (graphite)')
plt.xlabel('Wavenumber (cm⁻¹)')
plt.ylabel('Near-field signal (a.u.)')
plt.title('nano-FTIR of Graphite – 2nd Harmonic')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 21
#      18 eps_graphite = (10 + 4j) * np.ones_like(omega)
#      20 # ✅ Create model using the class directly
# ---> 21 model = snompy.TipSampleModel(
#      22     z_tip=z_tip,
#      23     A=A_tip,
#      24     R=tip_radius,
#      25     sample=[eps_graphite]
#      26 )
#      28 # Compute effective polarizability
#      29 alpha_eff = model.alpha(omega)
#
# AttributeError: module 'snompy' has no attribute 'TipSampleModel'

# %%
import snompy
print(dir(snompy))
# Out:
# ['Sample', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_defaults', '_utils', '_version', 'bulk_sample', 'defaults', 'demodulate', 'fdm', 'pdm', 'sample']

# %%
import numpy as np
import matplotlib.pyplot as plt
import snompy

# Wavenumber range (cm⁻¹)
frequencies = np.linspace(800, 1800, 300)

# Convert to angular frequency (rad/s)
c_cm_per_s = 2.998e10
omega = 2 * np.pi * c_cm_per_s * frequencies

# Define graphite permittivity (constant approx)
eps_graphite = (10 + 4j) * np.ones_like(omega)

# Create sample object (semi-infinite graphite)
sample = snompy.Sample(eps_graphite)

# Tip parameters
tip_radius = 30e-9
A_tip = 20e-9
z_tip = np.linspace(0, 60e-9, 512)

# Use point dipole model (pdm)
alpha_eff = snompy.pdm(
    omega=omega,
    sample=sample,
    R=tip_radius,
    z_tip=z_tip,
    A=A_tip
)

# Demodulate at 2nd harmonic
s2 = snompy.demodulate(alpha_eff, harmonic=2)

# Plot near-field signal
plt.figure(figsize=(8, 4))
plt.plot(frequencies, np.abs(s2), label='|s₂| (graphite)')
plt.xlabel('Wavenumber (cm⁻¹)')
plt.ylabel('Near-field signal (a.u.)')
plt.title('nano-FTIR of Graphite – 2nd Harmonic (PDM)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 16
#      13 eps_graphite = (10 + 4j) * np.ones_like(omega)
#      15 # Create sample object (semi-infinite graphite)
# ---> 16 sample = snompy.Sample(eps_graphite)
#      18 # Tip parameters
#      19 tip_radius = 30e-9
#
# File ~\anaconda3\Lib\site-packages\snompy\sample.py:124, in Sample.__init__(self, eps_stack, beta_stack, t_stack, eps_env, nu_vac)
#     122 self.t_stack = t_stack
#     123 if eps_stack is not None:
# --> 124     self.eps_stack = eps_stack
#     125 elif beta_stack is not None:
#     126     self.beta_stack = beta_stack
#
# File ~\anaconda3\Lib\site-packages\snompy\sample.py:152, in Sample.eps_stack(self, val)
#     149 self._eps_stack = np.asanyarray(np.broadcast_arrays(*val), dtype=complex)
#     151 # Check inputs make sense
# --> 152 self._check_layers_valid()
#
# File ~\anaconda3\Lib\site-packages\snompy\sample.py:461, in Sample._check_layers_valid(self)
#     459 if (self.t_stack is not None) and (self.eps_stack is not None):
#     460     if self.eps_stack.shape[0] != self.t_stack.shape[0] + 2:
# --> 461         raise ValueError(
#     462             " ".join(
#     463                 [
#     464                     "Invalid inputs:",
#     465                     "`eps_stack` must be 2 longer than `t_stack`, or",
#     466                     "`beta_stack` must be 1 longer than `t_stack`,",
#     467                     "along the first axis.",
#     468                 ]
#     469             )
#     470         )
#
# ValueError: Invalid inputs: `eps_stack` must be 2 longer than `t_stack`, or `beta_stack` must be 1 longer than `t_stack`, along the first axis.

# %%
import numpy as np
import matplotlib.pyplot as plt
import snompy

# Frequencies in cm⁻¹
frequencies = np.linspace(800, 1800, 300)

# Convert to angular frequency (rad/s)
c_cm_per_s = 2.998e10
omega = 2 * np.pi * c_cm_per_s * frequencies
  
# Layer permittivities (all arrays of shape (num_layers, num_freq))
eps_air = np.ones_like(omega)  # environment permittivity = 1
eps_graphite = (10 + 4j) * np.ones_like(omega)  # graphite permittivity
eps_substrate = np.ones_like(omega)  # substrate permittivity (air for now)

# Stack permittivities: env, graphite, substrate (3 layers)
eps_stack = np.array([eps_air, eps_graphite, eps_substrate])

# Thicknesses of intermediate layers (only graphite layer)
# Units: meters. For semi-infinite graphite, set a large thickness or None
t_stack = np.array([np.inf])  # infinite graphite layer thickness

# Create Sample object
sample = snompy.Sample(eps_stack=eps_stack, t_stack=t_stack)

# Tip parameters
tip_radius = 30e-9
A_tip = 20e-9
z_tip = np.linspace(0, 60e-9, 512)

# Use point dipole model (pdm)
alpha_eff = snompy.pdm(
    omega=omega,
    sample=sample,
    R=tip_radius,
    z_tip=z_tip,
    A=A_tip
)

# Demodulate 2nd harmonic
s2 = snompy.demodulate(alpha_eff, harmonic=2)

# Plot
plt.figure(figsize=(8, 4))
plt.plot(frequencies, np.abs(s2), label='|s₂| (graphite)')
plt.xlabel('Wavenumber (cm⁻¹)')
plt.ylabel('Near-field signal (a.u.)')
plt.title('nano-FTIR of Graphite – 2nd Harmonic (PDM)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 33
#      30 z_tip = np.linspace(0, 60e-9, 512)
#      32 # Use point dipole model (pdm)
# ---> 33 alpha_eff = snompy.pdm(
#      34     omega=omega,
#      35     sample=sample,
#      36     R=tip_radius,
#      37     z_tip=z_tip,
#      38     A=A_tip
#      39 )
#      41 # Demodulate 2nd harmonic
#      42 s2 = snompy.demodulate(alpha_eff, harmonic=2)
#
# TypeError: 'module' object is not callable

# %%
import numpy as np
import matplotlib.pyplot as plt
import snompy

# Define wavenumber range (cm⁻¹)
frequencies = np.linspace(800, 1800, 300)

# Convert to angular frequency (rad/s)
c_cm_per_s = 2.998e10
omega = 2 * np.pi * c_cm_per_s * frequencies

# Permittivities for environment, graphite, substrate (all shape (num_freq,))
eps_air = np.ones_like(omega)
eps_graphite = (10 + 4j) * np.ones_like(omega)
eps_substrate = np.ones_like(omega)  # air substrate for now

# Stack permittivities: environment, graphite, substrate
eps_stack = np.array([eps_air, eps_graphite, eps_substrate])

# Thickness of intermediate layers (graphite layer)
t_stack = np.array([np.inf])  # semi-infinite graphite

# Create sample
sample = snompy.Sample(eps_stack=eps_stack, t_stack=t_stack)

# Tip parameters
tip_radius = 30e-9  # 30 nm
A_tip = 20e-9       # Tapping amplitude 20 nm
z_tip = np.linspace(0, 60e-9, 512)  # Approach curve (0-60 nm)

# Compute effective polarizability using point dipole model
alpha_eff = snompy.pdm.alpha(
    omega=omega,
    sample=sample,
    R=tip_radius,
    z_tip=z_tip,
    A=A_tip
)

# Demodulate at 2nd harmonic
s2 = snompy.demodulate(alpha_eff, harmonic=2)

# Plot near-field signal magnitude
plt.figure(figsize=(8, 4))
plt.plot(frequencies, np.abs(s2), label='|s₂| (graphite)')
plt.xlabel('Wavenumber (cm⁻¹)')
plt.ylabel('Near-field signal (a.u.)')
plt.title('nano-FTIR of Graphite – 2nd Harmonic (PDM)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 32
#      29 z_tip = np.linspace(0, 60e-9, 512)  # Approach curve (0-60 nm)
#      31 # Compute effective polarizability using point dipole model
# ---> 32 alpha_eff = snompy.pdm.alpha(
#      33     omega=omega,
#      34     sample=sample,
#      35     R=tip_radius,
#      36     z_tip=z_tip,
#      37     A=A_tip
#      38 )
#      40 # Demodulate at 2nd harmonic
#      41 s2 = snompy.demodulate(alpha_eff, harmonic=2)
#
# AttributeError: module 'snompy.pdm' has no attribute 'alpha'

# %%
import numpy as np
import matplotlib.pyplot as plt
import snompy

# Define IR wavenumber range (cm⁻¹)
frequencies = np.linspace(800, 1800, 300)

# Convert to angular frequency (rad/s)
c_cm_per_s = 2.998e10
omega = 2 * np.pi * c_cm_per_s * frequencies

# Define permittivities for environment, graphite, and substrate
eps_air = np.ones_like(omega)                     # air (environment)
eps_graphite = (10 + 4j) * np.ones_like(omega)    # graphite permittivity (approximate)
eps_substrate = np.ones_like(omega)                # air substrate for simplicity

# Stack permittivities: environment, graphite, substrate
eps_stack = np.array([eps_air, eps_graphite, eps_substrate])

# Thickness of intermediate layers (graphite layer)
t_stack = np.array([np.inf])  # semi-infinite graphite

# Create sample object
sample = snompy.Sample(eps_stack=eps_stack, t_stack=t_stack)

# Tip parameters
tip_radius = 30e-9  # 30 nm
A_tip = 20e-9       # tapping amplitude 20 nm
z_tip = np.linspace(0, 60e-9, 512)  # tip approach positions (0 to 60 nm)

# Compute effective polarizability with point dipole model (pdm)
# Note: adjust the function name below based on your snompy version
alpha_eff = snompy.pdm.calc_alpha(
    omega=omega,
    sample=sample,
    R=tip_radius,
    z_tip=z_tip,
    A=A_tip
)

# Demodulate at 2nd harmonic
s2 = snompy.demodulate(alpha_eff, harmonic=2)

# Plot the near-field nano-FTIR signal magnitude
plt.figure(figsize=(8, 4))
plt.plot(frequencies, np.abs(s2), label='|s₂| (graphite)')
plt.xlabel('Wavenumber (cm⁻¹)')
plt.ylabel('Near-field signal (a.u.)')
plt.title('nano-FTIR Spectrum of Graphite (2nd harmonic, PDM)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 33
#      29 z_tip = np.linspace(0, 60e-9, 512)  # tip approach positions (0 to 60 nm)
#      31 # Compute effective polarizability with point dipole model (pdm)
#      32 # Note: adjust the function name below based on your snompy version
# ---> 33 alpha_eff = snompy.pdm.calc_alpha(
#      34     omega=omega,
#      35     sample=sample,
#      36     R=tip_radius,
#      37     z_tip=z_tip,
#      38     A=A_tip
#      39 )
#      41 # Demodulate at 2nd harmonic
#      42 s2 = snompy.demodulate(alpha_eff, harmonic=2)
#
# AttributeError: module 'snompy.pdm' has no attribute 'calc_alpha'

# %%
import numpy as np
import matplotlib.pyplot as plt
import snompy

# Frequencies (cm^-1)
freq = np.linspace(800, 1800, 300)
c = 2.998e10
omega = 2 * np.pi * c * freq

# Permittivities
eps_air = np.ones_like(omega)
eps_Si = (12 + 0.1j) * np.ones_like(omega)  # Approximate silicon permittivity
eps_stack = np.array([eps_air, eps_Si, eps_air])
t_stack = np.array([np.inf])  # Semi-infinite Si

# Create sample
sample = snompy.Sample(eps_stack=eps_stack, t_stack=t_stack)

# Tip parameters
R1 = 20e-9  # 20 nm tip radius
A = 20e-9
z_tip = np.linspace(0, 60e-9, 512)

# Compute near-field with point dipole model
alpha1 = snompy.pdm.calc_alpha(omega, sample=sample, R=R1, z_tip=z_tip, A=A)

# Demodulate 2nd harmonic
s2_1 = snompy.demodulate(alpha1, harmonic=2)

# Plot
plt.figure(figsize=(8,4))
plt.plot(freq, np.abs(s2_1), label="Tip radius = 20 nm")
plt.xlabel("Wavenumber (cm⁻¹)")
plt.ylabel("Near-field amplitude (a.u.)")
plt.title("nano-FTIR on Si with 20 nm tip radius")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 25
#      22 z_tip = np.linspace(0, 60e-9, 512)
#      24 # Compute near-field with point dipole model
# ---> 25 alpha1 = snompy.pdm.calc_alpha(omega, sample=sample, R=R1, z_tip=z_tip, A=A)
#      27 # Demodulate 2nd harmonic
#      28 s2_1 = snompy.demodulate(alpha1, harmonic=2)
#
# AttributeError: module 'snompy.pdm' has no attribute 'calc_alpha'

# %%
import snompy.pdm

print([f for f in dir(snompy.pdm) if callable(getattr(snompy.pdm, f)) and not f.startswith('_')])
# Out:
# ['Polynomial', 'demod', 'eff_pol', 'eff_pol_n', 'eff_pol_n_taylor', 'geom_func', 'permitivitty', 'refl_coef_qs_from_eff_pol', 'refl_coef_qs_from_eff_pol_n', 'taylor_coef']

# %% [markdown]
# #### import numpy as np
# import matplotlib.pyplot as plt
# import snompy
#
# freq = np.linspace(800, 1800, 300)
# c = 2.998e10
# omega = 2 * np.pi * c * freq
#
# eps_air = np.ones_like(omega)
# eps_Si = (12 + 0.1j) * np.ones_like(omega)
# eps_stack = np.array([eps_air, eps_Si, eps_air])
# t_stack = np.array([np.inf])
#
# sample = snompy.Sample(eps_stack=eps_stack, t_stack=t_stack)
#
# R1 = 20e-9
# R2 = 40e-9
# A = 20e-9
# z_tip = np.linspace(0, 60e-9, 512)
#
# # Compute effective polarizability for each tip radius
# alpha1 = snompy.pdm.eff_pol(omega, sample=sample, R=R1, z_tip=z_tip, A=A)
# alpha2 = snompy.pdm.eff_pol(omega, sample=sample, R=R2, z_tip=z_tip, A=A)
#
# # Demodulate 2nd harmonic
# s2_1 = snompy.demodulate(alpha1, harmonic=2)
# s2_2 = snompy.demodulate(alpha2, harmonic=2)
#
# plt.figure(figsize=(8,4))
# plt.plot(freq, np.abs(s2_1), label="Tip radius = 20 nm")
# plt.plot(freq, np.abs(s2_2), label="Tip radius = 40 nm")
# plt.xlabel("Wavenumber (cm⁻¹)")
# plt.ylabel("Near-field amplitude (a.u.)")
# plt.title("nano-FTIR on Si: Effect of Tip Radius")
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# Plot output
fig, axes = plt.subplots(nrows=2, sharex=True)

r_tips = [20e-9, 40e-9] # AFM tip radius of curvature

for i in range(2):
# Set some experimental parameters
A_tip = 20e-9 # AFM tip tapping amplitude
r_tip = r_tips[i] # AFM tip radius of curvature
L_tip = 350e-9 # Semi-major axis length of ellipsoid tip model
n = 3 # Harmonic for demodulation
theta_in = np.deg2rad(60) # Light angle of incidence
c_r = 0.3 # Experimental weighting factor
nu_vac = np.linspace(1680, 1800, 128) * 1e2 # Vacuum wavenumber
method = “Q_ave” # The FDM method to use

# Semi-infinite superstrate and substrate
eps_air = 1.0
eps_Si = 11.7 # Si permitivitty in the mid-infrared
# Out:
#   Cell In[1], line 21
#     method = “Q_ave” # The FDM method to use
#              ^
# SyntaxError: invalid character '“' (U+201C)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# Plot output
fig, axes = plt.subplots(nrows=2, sharex=True)

r_tips = [20e-9, 40e-9] # AFM tip radius of curvature

for i in range(2):
# Set some experimental parameters
A_tip = 20e-9 # AFM tip tapping amplitude
r_tip = r_tips[i] # AFM tip radius of curvature
L_tip = 350e-9 # Semi-major axis length of ellipsoid tip model
n = 3 # Harmonic for demodulation
theta_in = np.deg2rad(60) # Light angle of incidence
c_r = 0.3 # Experimental weighting factor
nu_vac = np.linspace(1680, 1800, 128) * 1e2 # Vacuum wavenumber
method = "Q_ave"  # The FDM method to use

# Semi-infinite superstrate and substrate
eps_air = 1.0
eps_Si = 11.7 # Si permitivitty in the mid-infrared
# Out:
#   Cell In[3], line 14
#     A_tip = 20e-9 # AFM tip tapping amplitude
#     ^
# IndentationError: expected an indented block after 'for' statement on line 12

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# Set some experimental parameters
A_tip = 20e-9  # AFM tip tapping amplitude
r_tip = 30e-9  # AFM tip radius of curvature
L_tip = 350e-9  # Semi-major axis length of ellipsoid tip model
n = 3  # Harmonic for demodulation
theta_in = np.deg2rad(60)  # Light angle of incidence
c_r = 0.3  # Experimental weighting factor
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # Vacuum wavenumber
method = "Q_ave"  # The FDM method to use

# Semi-infinite superstrate and substrate
eps_air = 1.0
eps_Si = 11.7  # Si permitivitty in the mid-infrared

# Very simplified model of PMMA dielectric function based on ref [1] below
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = np.geomspace(1, 35, 32) * 1e-9  # A range of thicknesses
sample_pmma = snompy.Sample(
    eps_stack=(eps_air, eps_pmma, eps_Si),
    t_stack=(t_pmma[:, np.newaxis],),
    nu_vac=nu_vac,
)

# Model of Au dielectric function from ref [2] below
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# Measurement
alpha_eff_pmma = snompy.fdm.eff_pol_n(
    sample=sample_pmma, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_pmma = sample_pmma.refl_coef(theta_in=theta_in)
sigma_pmma = (1 + c_r * r_coef_pmma) ** 2 * alpha_eff_pmma

# Gold reference
alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalised complex scattering
eta_n = sigma_pmma / sigma_Au

# Plot output
fig, axes = plt.subplots(nrows=2, sharex=True)

# For neater plotting
nu_per_cm = nu_vac * 1e-2
t_nm = t_pmma * 1e9

SM = plt.cm.ScalarMappable(
    cmap=plt.cm.Spectral_r, norm=Normalize(vmin=t_nm.min(), vmax=t_nm.max())
)  # This maps thickness to colour

for t, sigma in zip(t_nm, eta_n):
    c = SM.to_rgba(t)
    axes[0].plot(nu_per_cm, np.abs(sigma), c=c)
    axes[1].plot(nu_per_cm, np.angle(sigma), c=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
cbar = fig.colorbar(SM, ax=axes, label="PMMA thickness / nm")
plt.show(block=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# Set some experimental parameters
A_tip = 20e-9  # AFM tip tapping amplitude
r_tip = 30e-9  # AFM tip radius of curvature
L_tip = 350e-9  # Semi-major axis length of ellipsoid tip model
n = 3  # Harmonic for demodulation
theta_in = np.deg2rad(60)  # Light angle of incidence
c_r = 0.3  # Experimental weighting factor
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # Vacuum wavenumber
method = "Q_ave"  # The FDM method to use

# Semi-infinite superstrate and substrate
eps_air = 1.0
eps_H2O = 1.6  # H2O permitivitty in the mid-infrared

# Very simplified model of PMMA dielectric function based on ref [1] below
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = np.geomspace(1, 35, 32) * 1e-9  # A range of thicknesses
sample_pmma = snompy.Sample(
    eps_stack=(eps_air, eps_pmma, eps_Si),
    t_stack=(t_pmma[:, np.newaxis],),
    nu_vac=nu_vac,
)

# Model of Au dielectric function from ref [2] below
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# Measurement
alpha_eff_pmma = snompy.fdm.eff_pol_n(
    sample=sample_pmma, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_pmma = sample_pmma.refl_coef(theta_in=theta_in)
sigma_pmma = (1 + c_r * r_coef_pmma) ** 2 * alpha_eff_pmma

# Gold reference
alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalised complex scattering
eta_n = sigma_pmma / sigma_Au

# Plot output
fig, axes = plt.subplots(nrows=2, sharex=True)

# For neater plotting
nu_per_cm = nu_vac * 1e-2
t_nm = t_pmma * 1e9

SM = plt.cm.ScalarMappable(
    cmap=plt.cm.Spectral_r, norm=Normalize(vmin=t_nm.min(), vmax=t_nm.max())
)  # This maps thickness to colour

for t, sigma in zip(t_nm, eta_n):
    c = SM.to_rgba(t)
    axes[0].plot(nu_per_cm, np.abs(sigma), c=c)
    axes[1].plot(nu_per_cm, np.angle(sigma), c=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
cbar = fig.colorbar(SM, ax=axes, label="PMMA thickness / nm")
plt.show(block=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# Set some experimental parameters
A_tip = 20e-9  # AFM tip tapping amplitude
r_tip = 30e-9  # AFM tip radius of curvature
L_tip = 350e-9  # Semi-major axis length of ellipsoid tip model
n = 3  # Harmonic for demodulation
theta_in = np.deg2rad(60)  # Light angle of incidence
c_r = 0.3  # Experimental weighting factor
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # Vacuum wavenumber
method = "Q_ave"  # The FDM method to use

# Semi-infinite superstrate and substrate
eps_air = 1.0
eps_H2O = 1.6  # H2O permitivitty in the mid-infrared

# Very simplified model of SiNx dielectric function
eps_SiNx = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = np.geomspace(1, 35, 32) * 1e-9  # A range of thicknesses
sample_pmma = snompy.Sample(
    eps_stack=(eps_air, eps_pmma, eps_Si),
    t_stack=(t_pmma[:, np.newaxis],),
    nu_vac=nu_vac,
)

# Model of Au dielectric function from ref [2] below
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# Measurement
alpha_eff_pmma = snompy.fdm.eff_pol_n(
    sample=sample_pmma, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_pmma = sample_pmma.refl_coef(theta_in=theta_in)
sigma_pmma = (1 + c_r * r_coef_pmma) ** 2 * alpha_eff_pmma

# Gold reference
alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalised complex scattering
eta_n = sigma_pmma / sigma_Au

# Plot output
fig, axes = plt.subplots(nrows=2, sharex=True)

# For neater plotting
nu_per_cm = nu_vac * 1e-2
t_nm = t_pmma * 1e9

SM = plt.cm.ScalarMappable(
    cmap=plt.cm.Spectral_r, norm=Normalize(vmin=t_nm.min(), vmax=t_nm.max())
)  # This maps thickness to colour

for t, sigma in zip(t_nm, eta_n):
    c = SM.to_rgba(t)
    axes[0].plot(nu_per_cm, np.abs(sigma), c=c)
    axes[1].plot(nu_per_cm, np.angle(sigma), c=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
cbar = fig.colorbar(SM, ax=axes, label="PMMA thickness / nm")
plt.show(block=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize
import snompy

# Set some experimental parameters
A_tip = 20e-9   # AFM tip tapping amplitude
r_tip = 30e-9   # AFM tip radius of curvature
L_tip = 350e-9  # Semi-major axis length of ellipsoid tip model
n = 3           # Harmonic for demodulation
theta_in = np.deg2rad(60)  # Light angle of incidence
c_r = 0.3       # Experimental weighting factor
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # Vacuum wavenumber
method = "Q_ave"  # The FDM method to use

# Semi-infinite superstrate and substrate
eps_air = 1.0
eps_Si = 11.7  # Si permittivity in the mid-infrared

# Silicon nitride dielectric function (constant for mid-IR)
eps_si3n4 = np.full_like(nu_vac, 7.5)  # Real permittivity (n~2.74, k~0)
t_si3n4 = np.geomspace(1, 35, 32) * 1e-9  # A range of thicknesses
sample_si3n4 = snompy.Sample(
    eps_stack=(eps_air, eps_si3n4, eps_Si),
    t_stack=(t_si3n4[:, np.newaxis],),
    nu_vac=nu_vac,
)

# Gold reference
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# Measurement for Si3N4
alpha_eff_si3n4 = snompy.fdm.eff_pol_n(
    sample=sample_si3n4, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_si3n4 = sample_si3n4.refl_coef(theta_in=theta_in)
sigma_si3n4 = (1 + c_r * r_coef_si3n4) ** 2 * alpha_eff_si3n4

# Measurement for gold reference
alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalised complex scattering
eta_n = sigma_si3n4 / sigma_Au

# Plot output
fig, axes = plt.subplots(nrows=2, sharex=True)

nu_per_cm = nu_vac * 1e-2
t_nm = t_si3n4 * 1e9

SM = plt.cm.ScalarMappable(
    cmap=plt.cm.Spectral_r, norm=Normalize(vmin=t_nm.min(), vmax=t_nm.max())
)

for t, sigma in zip(t_nm, eta_n):
    c = SM.to_rgba(t)
    axes[0].plot(nu_per_cm, np.abs(sigma), c=c)
    axes[1].plot(nu_per_cm, np.angle(sigma), c=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
cbar = fig.colorbar(SM, ax=axes, label="Si$_3$N$_4$ thickness / nm")
plt.show(block=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize
import snompy

# Experimental parameters
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
n = 3
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # m⁻¹
method = "Q_ave"

# Permittivity of air
eps_air = 1.0

# Approximate permittivity of water in MIR (constant here for simplicity)
n_water = 1.25
k_water = 0.001
eps_water = (n_water + 1j * k_water) ** 2  # complex permittivity

# Si3N4 layer permittivity (constant)
eps_si3n4 = np.full_like(nu_vac, 7.5)

# Si3N4 thicknesses
t_si3n4 = np.geomspace(1, 35, 32) * 1e-9

# Create sample: air / Si3N4 / water
sample_si3n4_water = snompy.Sample(
    eps_stack=(eps_air, eps_si3n4, eps_water),
    t_stack=(t_si3n4[:, np.newaxis],),
    nu_vac=nu_vac,
)

# Gold reference sample
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# Measurement for Si3N4 on water
alpha_eff = snompy.fdm.eff_pol_n(
    sample=sample_si3n4_water, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef = sample_si3n4_water.refl_coef(theta_in=theta_in)
sigma = (1 + c_r * r_coef) ** 2 * alpha_eff

# Measurement for gold reference
alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalized scattering
eta_n = sigma / sigma_Au

# Plotting
fig, axes = plt.subplots(nrows=2, sharex=True)

nu_per_cm = nu_vac * 1e-2
t_nm = t_si3n4 * 1e9

SM = plt.cm.ScalarMappable(
    cmap=plt.cm.Spectral_r, norm=Normalize(vmin=t_nm.min(), vmax=t_nm.max())
)

for t, sigma_val in zip(t_nm, eta_n):
    c = SM.to_rgba(t)
    axes[0].plot(nu_per_cm, np.abs(sigma_val), c=c)
    axes[1].plot(nu_per_cm, np.angle(sigma_val), c=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
cbar = fig.colorbar(SM, ax=axes, label="Si$_3$N$_4$ thickness / nm")
plt.show(block=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize
import snompy

# Set experimental parameters (unchanged)
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
n = 3
theta_in = np.deg2rad(60)
c_r = 0.3

# --- IMPORTANT: updated spectral window to include Si3N4 and water absorption regions ---
nu_vac = np.linspace(400, 3600, 1024) * 1e2  # 400–3600 cm^-1 -> converted to m^-1

method = "Q_ave"

# Layers
eps_air = 1.0

# Quick Si3N4 approx (keep or replace with dataset later)
eps_si3n4 = np.full_like(nu_vac, 7.5)  # ~n=2.74, approximate, no dispersion in this simple model

# Quick water approx (simple constant complex refractive index)
n_water = 1.25
k_water = 0.001
eps_water = (n_water + 1j * k_water) ** 2  # constant complex permittivity (approx)

# Thickness sweep for Si3N4
t_si3n4 = np.geomspace(1, 35, 32) * 1e-9

# Build sample: air / Si3N4 / water
sample_si3n4_water = snompy.Sample(
    eps_stack=(eps_air, eps_si3n4, eps_water),
    t_stack=(t_si3n4[:, np.newaxis],),
    nu_vac=nu_vac,
)

# Gold reference (unchanged)
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# Simulate
alpha_eff = snompy.fdm.eff_pol_n(
    sample=sample_si3n4_water, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef = sample_si3n4_water.refl_coef(theta_in=theta_in)
sigma = (1 + c_r * r_coef) ** 2 * alpha_eff

alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalized scattering
eta_n = sigma / sigma_Au

# Plotting
fig, axes = plt.subplots(nrows=2, sharex=True, figsize=(7,6))
nu_per_cm = nu_vac * 1e-2
t_nm = t_si3n4 * 1e9

SM = plt.cm.ScalarMappable(
    cmap=plt.cm.Spectral_r, norm=Normalize(vmin=t_nm.min(), vmax=t_nm.max())
)

for t, sigma_val in zip(t_nm, eta_n):
    c = SM.to_rgba(t)
    axes[0].plot(nu_per_cm, np.abs(sigma_val), c=c, lw=0.9)
    axes[1].plot(nu_per_cm, np.angle(sigma_val), c=c, lw=0.9)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
cbar = fig.colorbar(SM, ax=axes, label="Si$_3$N$_4$ thickness / nm")
plt.show(block=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize
import snompy

# ----- experimental parameters -----
A_tip = 20e-9      # tip tapping amplitude
r_tip = 30e-9      # tip radius
L_tip = 350e-9     # ellipsoid semi-major axis
n = 3              # harmonic order
theta_in = np.deg2rad(60)
c_r = 0.3
method = "Q_ave"

# ----- spectral window (400 - 3600 cm^-1) -----
nu_vac = np.linspace(400, 3600, 1024) * 1e2  # convert cm^-1 -> m^-1

# ----- layers -----
eps_air = 1.0
# simple (non-dispersive) Si3N4 approximation
eps_si3n4 = np.full_like(nu_vac, 7.5)

# quick water approximation (complex, non-dispersive)
n_water = 1.2180
k_water = 0.0050800
eps_water = (n_water + 1j * k_water) ** 2

# ----- fixed Si3N4 thickness: 15 nm -----
t_si3n4 = np.array([15e-9])          # single thickness, shape (1,)
# snompy expects t_stack shape like (n_thicknesses, 1) -> use [:, np.newaxis]
sample = snompy.Sample(
    eps_stack=(eps_air, eps_si3n4, eps_water),
    t_stack=(t_si3n4[:, np.newaxis],),
    nu_vac=nu_vac,
)

# ----- gold reference -----
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# ----- simulate Si3N4-on-water -----
alpha_eff = snompy.fdm.eff_pol_n(
    sample=sample, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef = sample.refl_coef(theta_in=theta_in)
sigma = (1 + c_r * r_coef) ** 2 * alpha_eff

# ----- simulate gold reference -----
alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# ----- normalized scattering -----
eta_n = sigma / sigma_Au   # shape: (1, n_freq) if snompy keeps thickness axis first

# ----- plotting -----
nu_per_cm = nu_vac * 1e-2

fig, axes = plt.subplots(nrows=2, sharex=True, figsize=(8,6))
# eta_n may be (1, N) or (N,), safe indexing:
spec = eta_n[0] if eta_n.ndim == 2 else eta_n

axes[0].plot(nu_per_cm, np.abs(spec), lw=1.2)
axes[0].set_ylabel(r"$|s_{" f"{n}" r"}|$ (a.u.)")

axes[1].plot(nu_per_cm, np.angle(spec), lw=1.2)
axes[1].set_ylabel(r"$\phi_{" f"{n}" r"}$ (rad)")
axes[1].set_xlabel(r"$\nu$ / cm$^{-1}$")
axes[1].set_xlim(nu_per_cm.max(), nu_per_cm.min())  # reverse x axis (high -> low)

fig.tight_layout()
plt.show(block=False)

# %%
# realistic_si3n4_spectrum.py
import io
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize

import requests          # standard HTTP lib (should be installed)
import snompy

# --- user / simulation parameters ---
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
n_harm = 3
theta_in = np.deg2rad(60)
c_r = 0.3
method = "Q_ave"

# --- spectral window: 400 - 3600 cm^-1 (converted to m^-1) ---
nu_cm = np.linspace(400.0, 3600.0, 2048)      # cm^-1
nu_vac = nu_cm * 1e2                           # m^-1 (what snompy expects)

# --- download Si3N4 n,k dataset (Kischkat 2012) from refractiveindex.info ---
# Note: RefractiveIndex.info provides CSVs for many data sets (Kischkat covers 1.54-14.29 µm).
# URL pattern: https://refractiveindex.info/data_csv.php?datafile=database/data/main/Si3N4/nk/Kischkat.yml
rk_csv_url = ("https://refractiveindex.info/data_csv.php?"
              "datafile=database%2Fdata%2Fmain%2FSi3N4%2Fnk%2FKischkat.yml")

try:
    resp = requests.get(rk_csv_url, timeout=15)
    resp.raise_for_status()
    raw = resp.content.decode('utf-8')
    # RefractiveIndex CSV format often has header lines — we'll parse columns that look numeric.
    # The CSV usually contains wavelength (um), n, k. We'll try to load numeric columns robustly.
    data = np.genfromtxt(io.StringIO(raw), delimiter=',', comments='#', 
                         usecols=(0,1,2), invalid_raise=False)
    # Some rows may be empty or malformed; remove rows with NaN
    data = data[~np.any(np.isnan(data), axis=1)]
    if data.size == 0:
        raise ValueError("Parsed CSV is empty.")
    # The CSV's first column is wavelength (microns). Convert -> wavenumber cm^-1
    wl_um = data[:,0]             # microns
    n_data = data[:,1]
    k_data = data[:,2]
    # convert wavelength (um) to wavenumber (cm^-1): nu_cm = 1/(wl_um * 1e-4) = 1e4 / wl_um
    nu_data_cm = 1e4 / wl_um
    # Sort by increasing wavenumber (some datasets are descending)
    sort_idx = np.argsort(nu_data_cm)
    nu_data_cm = nu_data_cm[sort_idx]
    n_data = n_data[sort_idx]
    k_data = k_data[sort_idx]
except Exception as e:
    # Fallback: if download or parsing fails, use a smooth approximate model
    print("Warning: failed to download/parse Kischkat Si3N4 data - using fallback approx.\n", e)
    # Fallback: approximate n~2.0-2.9 slightly dispersive across MIR (very rough)
    # create a gentle dispersion so features still look physically plausible
    nu_data_cm = np.array([400, 800, 1200, 2000, 3000, 3600])
    n_data = np.array([2.45, 2.6, 2.8, 2.9, 2.85, 2.7])   # example trend
    k_data = np.zeros_like(n_data)

# --- interpolate n,k onto simulation grid (nu_cm) ---
# use linear interpolation in wavenumber space (extrapolate with nearest fill)
n_interp = np.interp(nu_cm, nu_data_cm, n_data, left=n_data[0], right=n_data[-1])
k_interp = np.interp(nu_cm, nu_data_cm, k_data, left=k_data[0], right=k_data[-1])

# complex refractive index and permittivity
n_complex = n_interp + 1j * k_interp
eps_si3n4 = n_complex**2   # eps(ν) = (n + i k)^2

# --- water permittivity (simple approximation; I can replace with measured dataset if you want) ---
# Keep the same simple water approx for now; this can be swapped for H2O experimental data.
n_water = 1.25
k_water = 0.001
eps_water = np.full_like(nu_vac, (n_water + 1j * k_water) ** 2)

# --- layers: air / Si3N4 / water ---
eps_air = 1.0
t_si3n4 = np.array([15e-9])           # fixed thickness 15 nm (shape (1,))
sample = snompy.Sample(
    eps_stack=(eps_air, eps_si3n4, eps_water) if False else (eps_air, eps_si3n4, 0),
    # NOTE: snompy.Sample expects eps_stack entries to be arrays of length = n_freq or scalars.
    # We must pass eps_si3n4 as an array of length len(nu_vac). However, the 'snompy' object
    # creation below depends on its API. We'll build eps_stack as:
)

# --- Build eps_stack correctly according to snompy expectations ---
# Many versions of snompy accept eps_stack with each layer either
#  - a scalar (non-dispersive) OR
#  - an array matching len(nu_vac).
# We'll ensure eps_si3n4 and eps_water are arrays of length len(nu_vac).
eps_si3n4_arr = eps_si3n4  # length == len(nu_vac)
eps_water_arr = eps_water  # length == len(nu_vac)

sample = snompy.Sample(
    eps_stack=(eps_air, eps_si3n4_arr, eps_water_arr),
    t_stack=(t_si3n4[:, np.newaxis],),
    nu_vac=nu_vac,
)

# --- gold reference ---
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# --- run simulation ---
alpha_eff = snompy.fdm.eff_pol_n(
    sample=sample, A_tip=A_tip, n=n_harm, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef = sample.refl_coef(theta_in=theta_in)
sigma = (1 + c_r * r_coef) ** 2 * alpha_eff

alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n_harm, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

eta_n = sigma / sigma_Au
spec = eta_n[0] if eta_n.ndim == 2 else eta_n

# --- plotting ---
nu_per_cm = nu_vac * 1e-2

fig, axes = plt.subplots(nrows=2, sharex=True, figsize=(9,6))
axes[0].plot(nu_per_cm, np.abs(spec), lw=1.2)
axes[0].set_ylabel(r"$|s_{" + f"{n_harm}" + r"}|$ (a.u.)")
axes[0].set_title("Si$_3$N$_4$ (Kischkat 2012) — 15 nm on water (approx)")

axes[1].plot(nu_per_cm, np.angle(spec), lw=1.2)
axes[1].set_ylabel(r"$\phi_{" + f"{n_harm}" + r"}$ (rad)")
axes[1].set_xlabel(r"$\nu$ / cm$^{-1}$")
axes[1].set_xlim(nu_per_cm.max(), nu_per_cm.min())

fig.tight_layout()
plt.show(block=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17012\1365254431.py:35: ConversionWarning: Some errors were detected !
#     Line #1 (got 2 columns instead of 3)
#     Line #2 (got 2 columns instead of 3)
#     Line #3 (got 2 columns instead of 3)
#     Line #4 (got 2 columns instead of 3)
#     Line #5 (got 2 columns instead of 3)
#     Line #6 (got 2 columns instead of 3)
#     Line #7 (got 2 columns instead of 3)
#     Line #8 (got 2 columns instead of 3)
#     Line #9 (got 2 columns instead of 3)
#     Line #10 (got 2 columns instead of 3)
#     Line #11 (got 2 columns instead of 3)
#     Line #12 (got 2 columns instead of 3)
#     Line #13 (got 2 columns instead of 3)
#     Line #14 (got 2 columns instead of 3)
#     Line #15 (got 2 columns instead of 3)
#     Line #16 (got 2 columns instead of 3)
#     Line #17 (got 2 columns instead of 3)
#     Line #18 (got 2 columns instead of 3)
#     Line #19 (got 2 columns instead of 3)
#     Line #20 (got 2 columns instead of 3)
#     Line #21 (got 2 columns instead of 3)
#     Line #22 (got 2 columns instead of 3)
#     Line #23 (got 2 columns instead of 3)
#     Line #24 (got 2 columns instead of 3)
#     Line #25 (got 2 columns instead of 3)
#     Line #26 (got 2 columns instead of 3)
#     Line #27 (got 2 columns instead of 3)
#     Line #28 (got 2 columns instead of 3)
#     Line #29 (got 2 columns instead of 3)
#     Line #30 (got 2 columns instead of 3)
#     Line #31 (got 2 columns instead of 3)
#     Line #32 (got 2 columns instead of 3)
#     Line #33 (got 2 columns instead of 3)
#     Line #34 (got 2 columns instead of 3)
#     Line #35 (got 2 columns instead of 3)
#     Line #36 (got 2 columns instead of 3)
#     Line #37 (got 2 columns instead of 3)
#     Line #38 (got 2 columns instead of 3)
#     Line #39 (got 2 columns instead of 3)
#     Line #40 (got 2 columns instead of 3)
#     Line #41 (got 2 columns instead of 3)
#     Line #42 (got 2 columns instead of 3)
#     Line #43 (got 2 columns instead of 3)
#     Line #44 (got 2 columns instead of 3)
#     Line #45 (got 2 columns instead of 3)
#     Line #46 (got 2 columns instead of 3)
#     Line #47 (got 2 columns instead of 3)
#     Line #48 (got 2 columns instead of 3)
#     Line #49 (got 2 columns instead of 3)
#     Line #50 (got 2 columns instead of 3)
#     Line #51 (got 2 columns instead of 3)
#     Line #52 (got 2 columns instead of 3)
#     Line #53 (got 2 columns instead of 3)
#     Line #54 (got 2 columns instead of 3)
#     Line #55 (got 2 columns instead of 3)
#     Line #56 (got 2 columns instead of 3)
#     Line #57 (got 2 columns instead of 3)
#     Line #58 (got 2 columns instead of 3)
#     Line #59 (got 2 columns instead of 3)
#     Line #60 (got 2 columns instead of 3)
#     Line #61 (got 2 columns instead of 3)
#     Line #62 (got 2 columns instead of 3)
#     Line #63 (got 2 columns instead of 3)
#     Line #64 (got 2 columns instead of 3)
#     Line #65 (got 2 columns instead of 3)
#     Line #66 (got 2 columns instead of 3)
#     Line #67 (got 2 columns instead of 3)
#     Line #68 (got 2 columns instead of 3)
#     Line #69 (got 2 columns instead of 3)
#     Line #70 (got 2 columns instead of 3)
#     Line #71 (got 2 columns instead of 3)
#     Line #72 (got 2 columns instead of 3)
#     Line #73 (got 2 columns instead of 3)
#     Line #74 (got 2 columns instead of 3)
#     Line #75 (got 2 columns instead of 3)
#     Line #76 (got 2 columns instead of 3)
#     Line #77 (got 2 columns instead of 3)
#     Line #78 (got 2 columns instead of 3)
#     Line #79 (got 2 columns instead of 3)
#     Line #80 (got 2 columns instead of 3)
#     Line #81 (got 2 columns instead of 3)
#     Line #82 (got 2 columns instead of 3)
#     Line #83 (got 2 columns instead of 3)
#     Line #84 (got 2 columns instead of 3)
#     Line #85 (got 2 columns instead of 3)
#     Line #86 (got 2 columns instead of 3)
#     Line #87 (got 2 columns instead of 3)
#     Line #88 (got 2 columns instead of 3)
#     Line #89 (got 2 columns instead of 3)
#     Line #90 (got 2 columns instead of 3)
#     Line #91 (got 2 columns instead of 3)
#     Line #92 (got 2 columns instead of 3)
#     Line #93 (got 2 columns instead of 3)
#     Line #94 (got 2 columns instead of 3)
#     Line #95 (got 2 columns instead of 3)
#     Line #96 (got 2 columns instead of 3)
#     Line #97 (got 2 columns instead of 3)
#     Line #98 (got 2 columns instead of 3)
#     Line #99 (got 2 columns instead of 3)
#     Line #100 (got 2 columns instead of 3)
#     Line #101 (got 2 columns instead of 3)
#     Line #102 (got 2 columns instead of 3)
#     Line #103 (got 2 columns instead of 3)
#     Line #104 (got 2 columns instead of 3)
#     Line #105 (got 2 columns instead of 3)
#     Line #106 (got 2 columns instead of 3)
#     Line #107 (got 2 columns instead of 3)
#     Line #108 (got 2 columns instead of 3)
#     Line #109 (got 2 columns instead of 3)
#     Line #110 (got 2 columns instead of 3)
#     Line #111 (got 2 columns instead of 3)
#     Line #112 (got 2 columns instead of 3)
#     Line #113 (got 2 columns instead of 3)
#     Line #114 (got 2 columns instead of 3)
#     Line #115 (got 2 columns instead of 3)
#     Line #116 (got 2 columns instead of 3)
#     Line #117 (got 2 columns instead of 3)
#     Line #118 (got 2 columns instead of 3)
#     Line #119 (got 2 columns instead of 3)
#     Line #120 (got 2 columns instead of 3)
#     Line #121 (got 2 columns instead of 3)
#     Line #122 (got 2 columns instead of 3)
#     Line #123 (got 2 columns instead of 3)
#     Line #124 (got 2 columns instead of 3)
#     Line #125 (got 2 columns instead of 3)
#     Line #126 (got 2 columns instead of 3)
#     Line #127 (got 2 columns instead of 3)
#     Line #128 (got 2 columns instead of 3)
#     Line #129 (got 2 columns instead of 3)
#     Line #130 (got 2 columns instead of 3)
#     Line #131 (got 2 columns instead of 3)
#     Line #132 (got 2 columns instead of 3)
#     Line #133 (got 2 columns instead of 3)
#     Line #134 (got 2 columns instead of 3)
#     Line #135 (got 2 columns instead of 3)
#     Line #136 (got 2 columns instead of 3)
#     Line #137 (got 2 columns instead of 3)
#     Line #138 (got 2 columns instead of 3)
#     Line #139 (got 2 columns instead of 3)
#     Line #140 (got 2 columns instead of 3)
#     Line #141 (got 2 columns instead of 3)
#     Line #142 (got 2 columns instead of 3)
#     Line #143 (got 2 columns instead of 3)
#     Line #144 (got 2 columns instead of 3)
#     Line #145 (got 2 columns instead of 3)
#     Line #146 (got 2 columns instead of 3)
#     Line #147 (got 2 columns instead of 3)
#     Line #148 (got 2 columns instead of 3)
#     Line #149 (got 2 columns instead of 3)
#     Line #150 (got 2 columns instead of 3)
#     Line #151 (got 2 columns instead of 3)
#     Line #152 (got 2 columns instead of 3)
#     Line #153 (got 2 columns instead of 3)
#     Line #154 (got 2 columns instead of 3)
#     Line #155 (got 2 columns instead of 3)
#     Line #156 (got 2 columns instead of 3)
#     Line #157 (got 2 columns instead of 3)
#     Line #158 (got 2 columns instead of 3)
#     Line #159 (got 2 columns instead of 3)
#     Line #160 (got 2 columns instead of 3)
#     Line #161 (got 2 columns instead of 3)
#     Line #162 (got 2 columns instead of 3)
#     Line #163 (got 2 columns instead of 3)
#     Line #164 (got 2 columns instead of 3)
#     Line #165 (got 2 columns instead of 3)
#     Line #166 (got 2 columns instead of 3)
#     Line #167 (got 2 columns instead of 3)
#     Line #168 (got 2 columns instead of 3)
#     Line #169 (got 2 columns instead of 3)
#     Line #170 (got 2 columns instead of 3)
#     Line #171 (got 2 columns instead of 3)
#     Line #172 (got 2 columns instead of 3)
#     Line #173 (got 2 columns instead of 3)
#     Line #174 (got 2 columns instead of 3)
#     Line #175 (got 2 columns instead of 3)
#     Line #176 (got 2 columns instead of 3)
#     Line #177 (got 2 columns instead of 3)
#     Line #178 (got 2 columns instead of 3)
#     Line #179 (got 2 columns instead of 3)
#     Line #180 (got 2 columns instead of 3)
#     Line #181 (got 2 columns instead of 3)
#     Line #182 (got 2 columns instead of 3)
#     Line #183 (got 2 columns instead of 3)
#     Line #184 (got 2 columns instead of 3)
#     Line #185 (got 2 columns instead of 3)
#     Line #186 (got 2 columns instead of 3)
#     Line #187 (got 2 columns instead of 3)
#     Line #188 (got 2 columns instead of 3)
#     Line #189 (got 2 columns instead of 3)
#     Line #190 (got 2 columns instead of 3)
#     Line #191 (got 2 columns instead of 3)
#     Line #192 (got 2 columns instead of 3)
#     Line #193 (got 2 columns instead of 3)
#     Line #194 (got 2 columns instead of 3)
#     Line #195 (got 2 columns instead of 3)
#     Line #196 (got 2 columns instead of 3)
#     Line #197 (got 2 columns instead of 3)
#     Line #198 (got 2 columns instead of 3)
#     Line #199 (got 2 columns instead of 3)
#     Line #200 (got 2 columns instead of 3)
#     Line #201 (got 2 columns instead of 3)
#     Line #202 (got 2 columns instead of 3)
#     Line #203 (got 2 columns instead of 3)
#     Line #204 (got 2 columns instead of 3)
#     Line #205 (got 2 columns instead of 3)
#     Line #206 (got 2 columns instead of 3)
#     Line #207 (got 2 columns instead of 3)
#     Line #208 (got 2 columns instead of 3)
#     Line #209 (got 2 columns instead of 3)
#     Line #210 (got 2 columns instead of 3)
#     Line #211 (got 2 columns instead of 3)
#     Line #212 (got 2 columns instead of 3)
#     Line #213 (got 2 columns instead of 3)
#     Line #214 (got 2 columns instead of 3)
#     Line #215 (got 2 columns instead of 3)
#     Line #216 (got 2 columns instead of 3)
#     Line #217 (got 2 columns instead of 3)
#     Line #218 (got 2 columns instead of 3)
#     Line #219 (got 2 columns instead of 3)
#     Line #220 (got 2 columns instead of 3)
#     Line #221 (got 2 columns instead of 3)
#     Line #222 (got 2 columns instead of 3)
#     Line #223 (got 2 columns instead of 3)
#     Line #224 (got 2 columns instead of 3)
#     Line #225 (got 2 columns instead of 3)
#     Line #226 (got 2 columns instead of 3)
#     Line #227 (got 2 columns instead of 3)
#     Line #228 (got 2 columns instead of 3)
#     Line #229 (got 2 columns instead of 3)
#     Line #230 (got 2 columns instead of 3)
#     Line #231 (got 2 columns instead of 3)
#     Line #232 (got 2 columns instead of 3)
#     Line #233 (got 2 columns instead of 3)
#     Line #234 (got 2 columns instead of 3)
#     Line #235 (got 2 columns instead of 3)
#     Line #236 (got 2 columns instead of 3)
#     Line #237 (got 2 columns instead of 3)
#     Line #238 (got 2 columns instead of 3)
#     Line #239 (got 2 columns instead of 3)
#     Line #240 (got 2 columns instead of 3)
#     Line #241 (got 2 columns instead of 3)
#     Line #242 (got 2 columns instead of 3)
#     Line #243 (got 2 columns instead of 3)
#     Line #244 (got 2 columns instead of 3)
#     Line #245 (got 2 columns instead of 3)
#     Line #246 (got 2 columns instead of 3)
#     Line #247 (got 2 columns instead of 3)
#     Line #248 (got 2 columns instead of 3)
#     Line #249 (got 2 columns instead of 3)
#     Line #250 (got 2 columns instead of 3)
#     Line #251 (got 2 columns instead of 3)
#     Line #252 (got 2 columns instead of 3)
#     Line #253 (got 2 columns instead of 3)
#     Line #254 (got 2 columns instead of 3)
#     Line #255 (got 2 columns instead of 3)
#     Line #256 (got 2 columns instead of 3)
#     Line #257 (got 2 columns instead of 3)
#     Line #258 (got 2 columns instead of 3)
#     Line #259 (got 2 columns instead of 3)
#     Line #260 (got 2 columns instead of 3)
#     Line #261 (got 2 columns instead of 3)
#     Line #262 (got 2 columns instead of 3)
#     Line #263 (got 2 columns instead of 3)
#     Line #264 (got 2 columns instead of 3)
#     Line #265 (got 2 columns instead of 3)
#     Line #266 (got 2 columns instead of 3)
#     Line #267 (got 2 columns instead of 3)
#     Line #268 (got 2 columns instead of 3)
#     Line #269 (got 2 columns instead of 3)
#     Line #270 (got 2 columns instead of 3)
#     Line #271 (got 2 columns instead of 3)
#     Line #272 (got 2 columns instead of 3)
#     Line #273 (got 2 columns instead of 3)
#     Line #274 (got 2 columns instead of 3)
#     Line #275 (got 2 columns instead of 3)
#     Line #276 (got 2 columns instead of 3)
#     Line #277 (got 2 columns instead of 3)
#     Line #278 (got 2 columns instead of 3)
#     Line #279 (got 2 columns instead of 3)
#     Line #280 (got 2 columns instead of 3)
#     Line #281 (got 2 columns instead of 3)
#     Line #282 (got 2 columns instead of 3)
#     Line #283 (got 2 columns instead of 3)
#     Line #284 (got 2 columns instead of 3)
#     Line #285 (got 2 columns instead of 3)
#     Line #286 (got 2 columns instead of 3)
#     Line #287 (got 2 columns instead of 3)
#     Line #288 (got 2 columns instead of 3)
#     Line #289 (got 2 columns instead of 3)
#     Line #290 (got 2 columns instead of 3)
#     Line #291 (got 2 columns instead of 3)
#     Line #292 (got 2 columns instead of 3)
#     Line #293 (got 2 columns instead of 3)
#     Line #294 (got 2 columns instead of 3)
#     Line #295 (got 2 columns instead of 3)
#     Line #296 (got 2 columns instead of 3)
#     Line #297 (got 2 columns instead of 3)
#     Line #298 (got 2 columns instead of 3)
#     Line #299 (got 2 columns instead of 3)
#     Line #300 (got 2 columns instead of 3)
#     Line #301 (got 2 columns instead of 3)
#     Line #302 (got 2 columns instead of 3)
#     Line #303 (got 2 columns instead of 3)
#     Line #304 (got 2 columns instead of 3)
#     Line #305 (got 2 columns instead of 3)
#     Line #306 (got 2 columns instead of 3)
#     Line #307 (got 2 columns instead of 3)
#     Line #308 (got 2 columns instead of 3)
#     Line #309 (got 2 columns instead of 3)
#     Line #310 (got 2 columns instead of 3)
#     Line #311 (got 2 columns instead of 3)
#     Line #312 (got 2 columns instead of 3)
#     Line #313 (got 2 columns instead of 3)
#     Line #314 (got 2 columns instead of 3)
#     Line #315 (got 2 columns instead of 3)
#     Line #316 (got 2 columns instead of 3)
#     Line #317 (got 2 columns instead of 3)
#     Line #318 (got 2 columns instead of 3)
#     Line #319 (got 2 columns instead of 3)
#     Line #320 (got 2 columns instead of 3)
#     Line #321 (got 2 columns instead of 3)
#     Line #322 (got 2 columns instead of 3)
#     Line #323 (got 2 columns instead of 3)
#     Line #324 (got 2 columns instead of 3)
#     Line #325 (got 2 columns instead of 3)
#     Line #326 (got 2 columns instead of 3)
#     Line #327 (got 2 columns instead of 3)
#     Line #328 (got 2 columns instead of 3)
#     Line #329 (got 2 columns instead of 3)
#     Line #330 (got 2 columns instead of 3)
#     Line #331 (got 2 columns instead of 3)
#     Line #332 (got 2 columns instead of 3)
#     Line #333 (got 2 columns instead of 3)
#     Line #334 (got 2 columns instead of 3)
#     Line #335 (got 2 columns instead of 3)
#     Line #336 (got 2 columns instead of 3)
#     Line #337 (got 2 columns instead of 3)
#     Line #338 (got 2 columns instead of 3)
#     Line #339 (got 2 columns instead of 3)
#     Line #340 (got 2 columns instead of 3)
#     Line #341 (got 2 columns instead of 3)
#     Line #342 (got 2 columns instead of 3)
#     Line #343 (got 2 columns instead of 3)
#     Line #344 (got 2 columns instead of 3)
#     Line #345 (got 2 columns instead of 3)
#     Line #346 (got 2 columns instead of 3)
#     Line #347 (got 2 columns instead of 3)
#     Line #348 (got 2 columns instead of 3)
#     Line #349 (got 2 columns instead of 3)
#     Line #350 (got 2 columns instead of 3)
#     Line #351 (got 2 columns instead of 3)
#     Line #352 (got 2 columns instead of 3)
#     Line #353 (got 2 columns instead of 3)
#     Line #354 (got 2 columns instead of 3)
#     Line #355 (got 2 columns instead of 3)
#     Line #356 (got 2 columns instead of 3)
#     Line #357 (got 2 columns instead of 3)
#     Line #358 (got 2 columns instead of 3)
#     Line #359 (got 2 columns instead of 3)
#     Line #360 (got 2 columns instead of 3)
#     Line #361 (got 2 columns instead of 3)
#     Line #362 (got 2 columns instead of 3)
#     Line #363 (got 2 columns instead of 3)
#     Line #364 (got 2 columns instead of 3)
#     Line #365 (got 2 columns instead of 3)
#     Line #366 (got 2 columns instead of 3)
#     Line #367 (got 2 columns instead of 3)
#     Line #368 (got 2 columns instead of 3)
#     Line #369 (got 2 columns instead of 3)
#     Line #370 (got 2 columns instead of 3)
#     Line #371 (got 2 columns instead of 3)
#     Line #372 (got 2 columns instead of 3)
#     Line #373 (got 2 columns instead of 3)
#     Line #374 (got 2 columns instead of 3)
#     Line #375 (got 2 columns instead of 3)
#     Line #376 (got 2 columns instead of 3)
#     Line #377 (got 2 columns instead of 3)
#     Line #378 (got 2 columns instead of 3)
#     Line #379 (got 2 columns instead of 3)
#     Line #380 (got 2 columns instead of 3)
#     Line #381 (got 2 columns instead of 3)
#     Line #382 (got 2 columns instead of 3)
#     Line #383 (got 2 columns instead of 3)
#     Line #384 (got 2 columns instead of 3)
#     Line #385 (got 2 columns instead of 3)
#     Line #386 (got 2 columns instead of 3)
#     Line #387 (got 2 columns instead of 3)
#     Line #388 (got 2 columns instead of 3)
#     Line #389 (got 2 columns instead of 3)
#     Line #390 (got 2 columns instead of 3)
#     Line #391 (got 2 columns instead of 3)
#     Line #392 (got 2 columns instead of 3)
#     Line #393 (got 2 columns instead of 3)
#     Line #394 (got 2 columns instead of 3)
#     Line #395 (got 2 columns instead of 3)
#     Line #396 (got 2 columns instead of 3)
#     Line #397 (got 2 columns instead of 3)
#     Line #398 (got 2 columns instead of 3)
#     Line #399 (got 2 columns instead of 3)
#     Line #400 (got 2 columns instead of 3)
#     Line #401 (got 2 columns instead of 3)
#     Line #402 (got 2 columns instead of 3)
#     Line #403 (got 2 columns instead of 3)
#     Line #404 (got 2 columns instead of 3)
#     Line #405 (got 2 columns instead of 3)
#     Line #406 (got 2 columns instead of 3)
#     Line #407 (got 2 columns instead of 3)
#     Line #408 (got 2 columns instead of 3)
#     Line #409 (got 2 columns instead of 3)
#     Line #410 (got 2 columns instead of 3)
#     Line #411 (got 2 columns instead of 3)
#     Line #412 (got 2 columns instead of 3)
#     Line #413 (got 2 columns instead of 3)
#     Line #414 (got 2 columns instead of 3)
#     Line #415 (got 2 columns instead of 3)
#     Line #416 (got 2 columns instead of 3)
#     Line #417 (got 2 columns instead of 3)
#     Line #418 (got 2 columns instead of 3)
#     Line #419 (got 2 columns instead of 3)
#     Line #420 (got 2 columns instead of 3)
#     Line #421 (got 2 columns instead of 3)
#     Line #422 (got 2 columns instead of 3)
#     Line #423 (got 2 columns instead of 3)
#     Line #424 (got 2 columns instead of 3)
#     Line #425 (got 2 columns instead of 3)
#     Line #426 (got 2 columns instead of 3)
#     Line #427 (got 2 columns instead of 3)
#     Line #428 (got 2 columns instead of 3)
#     Line #429 (got 2 columns instead of 3)
#     Line #430 (got 2 columns instead of 3)
#     Line #431 (got 2 columns instead of 3)
#     Line #432 (got 2 columns instead of 3)
#     Line #433 (got 2 columns instead of 3)
#     Line #434 (got 2 columns instead of 3)
#     Line #435 (got 2 columns instead of 3)
#     Line #436 (got 2 columns instead of 3)
#     Line #437 (got 2 columns instead of 3)
#     Line #438 (got 2 columns instead of 3)
#     Line #439 (got 2 columns instead of 3)
#     Line #440 (got 2 columns instead of 3)
#     Line #441 (got 2 columns instead of 3)
#     Line #442 (got 2 columns instead of 3)
#     Line #443 (got 2 columns instead of 3)
#     Line #444 (got 2 columns instead of 3)
#     Line #445 (got 2 columns instead of 3)
#     Line #446 (got 2 columns instead of 3)
#     Line #447 (got 2 columns instead of 3)
#     Line #448 (got 2 columns instead of 3)
#     Line #449 (got 2 columns instead of 3)
#     Line #450 (got 2 columns instead of 3)
#     Line #451 (got 2 columns instead of 3)
#     Line #452 (got 2 columns instead of 3)
#     Line #453 (got 2 columns instead of 3)
#     Line #454 (got 2 columns instead of 3)
#     Line #455 (got 2 columns instead of 3)
#     Line #456 (got 2 columns instead of 3)
#     Line #457 (got 2 columns instead of 3)
#     Line #458 (got 2 columns instead of 3)
#     Line #459 (got 2 columns instead of 3)
#     Line #460 (got 2 columns instead of 3)
#     Line #461 (got 2 columns instead of 3)
#     Line #462 (got 2 columns instead of 3)
#     Line #463 (got 2 columns instead of 3)
#     Line #464 (got 2 columns instead of 3)
#     Line #465 (got 2 columns instead of 3)
#     Line #466 (got 2 columns instead of 3)
#     Line #467 (got 2 columns instead of 3)
#     Line #468 (got 2 columns instead of 3)
#     Line #469 (got 2 columns instead of 3)
#     Line #470 (got 2 columns instead of 3)
#     Line #471 (got 2 columns instead of 3)
#     Line #472 (got 2 columns instead of 3)
#     Line #473 (got 2 columns instead of 3)
#     Line #474 (got 2 columns instead of 3)
#     Line #475 (got 2 columns instead of 3)
#     Line #476 (got 2 columns instead of 3)
#     Line #477 (got 2 columns instead of 3)
#     Line #478 (got 2 columns instead of 3)
#     Line #479 (got 2 columns instead of 3)
#     Line #480 (got 2 columns instead of 3)
#     Line #481 (got 2 columns instead of 3)
#     Line #482 (got 2 columns instead of 3)
#     Line #483 (got 2 columns instead of 3)
#     Line #484 (got 2 columns instead of 3)
#     Line #485 (got 2 columns instead of 3)
#     Line #486 (got 2 columns instead of 3)
#     Line #487 (got 2 columns instead of 3)
#     Line #488 (got 2 columns instead of 3)
#     Line #489 (got 2 columns instead of 3)
#     Line #490 (got 2 columns instead of 3)
#     Line #491 (got 2 columns instead of 3)
#     Line #492 (got 2 columns instead of 3)
#     Line #493 (got 2 columns instead of 3)
#     Line #494 (got 2 columns instead of 3)
#     Line #495 (got 2 columns instead of 3)
#     Line #496 (got 2 columns instead of 3)
#     Line #497 (got 2 columns instead of 3)
#     Line #498 (got 2 columns instead of 3)
#     Line #499 (got 2 columns instead of 3)
#     Line #500 (got 2 columns instead of 3)
#     Line #501 (got 2 columns instead of 3)
#     Line #502 (got 2 columns instead of 3)
#     Line #503 (got 2 columns instead of 3)
#     Line #504 (got 2 columns instead of 3)
#     Line #505 (got 2 columns instead of 3)
#     Line #506 (got 2 columns instead of 3)
#     Line #507 (got 2 columns instead of 3)
#     Line #508 (got 2 columns instead of 3)
#     Line #509 (got 2 columns instead of 3)
#     Line #510 (got 2 columns instead of 3)
#     Line #511 (got 2 columns instead of 3)
#     Line #512 (got 2 columns instead of 3)
#     Line #513 (got 2 columns instead of 3)
#     Line #514 (got 2 columns instead of 3)
#     Line #515 (got 2 columns instead of 3)
#     Line #516 (got 2 columns instead of 3)
#     Line #517 (got 2 columns instead of 3)
#     Line #518 (got 2 columns instead of 3)
#     Line #519 (got 2 columns instead of 3)
#     Line #520 (got 2 columns instead of 3)
#     Line #521 (got 2 columns instead of 3)
#     Line #522 (got 2 columns instead of 3)
#     Line #523 (got 2 columns instead of 3)
#     Line #524 (got 2 columns instead of 3)
#     Line #525 (got 2 columns instead of 3)
#     Line #526 (got 2 columns instead of 3)
#     Line #527 (got 2 columns instead of 3)
#     Line #528 (got 2 columns instead of 3)
#     Line #529 (got 2 columns instead of 3)
#     Line #530 (got 2 columns instead of 3)
#     Line #531 (got 2 columns instead of 3)
#     Line #532 (got 2 columns instead of 3)
#     Line #533 (got 2 columns instead of 3)
#     Line #534 (got 2 columns instead of 3)
#     Line #535 (got 2 columns instead of 3)
#     Line #536 (got 2 columns instead of 3)
#     Line #537 (got 2 columns instead of 3)
#     Line #538 (got 2 columns instead of 3)
#     Line #539 (got 2 columns instead of 3)
#     Line #540 (got 2 columns instead of 3)
#     Line #541 (got 2 columns instead of 3)
#     Line #542 (got 2 columns instead of 3)
#     Line #543 (got 2 columns instead of 3)
#     Line #544 (got 2 columns instead of 3)
#     Line #545 (got 2 columns instead of 3)
#     Line #546 (got 2 columns instead of 3)
#     Line #547 (got 2 columns instead of 3)
#     Line #548 (got 2 columns instead of 3)
#     Line #549 (got 2 columns instead of 3)
#     Line #550 (got 2 columns instead of 3)
#     Line #551 (got 2 columns instead of 3)
#     Line #552 (got 2 columns instead of 3)
#     Line #553 (got 2 columns instead of 3)
#     Line #554 (got 2 columns instead of 3)
#     Line #555 (got 2 columns instead of 3)
#     Line #556 (got 2 columns instead of 3)
#     Line #557 (got 2 columns instead of 3)
#     Line #558 (got 2 columns instead of 3)
#     Line #559 (got 2 columns instead of 3)
#     Line #560 (got 2 columns instead of 3)
#     Line #561 (got 2 columns instead of 3)
#     Line #562 (got 2 columns instead of 3)
#     Line #563 (got 2 columns instead of 3)
#     Line #564 (got 2 columns instead of 3)
#     Line #565 (got 2 columns instead of 3)
#     Line #566 (got 2 columns instead of 3)
#     Line #567 (got 2 columns instead of 3)
#     Line #568 (got 2 columns instead of 3)
#     Line #569 (got 2 columns instead of 3)
#     Line #570 (got 2 columns instead of 3)
#     Line #571 (got 2 columns instead of 3)
#     Line #572 (got 2 columns instead of 3)
#     Line #573 (got 2 columns instead of 3)
#     Line #574 (got 2 columns instead of 3)
#     Line #575 (got 2 columns instead of 3)
#     Line #576 (got 2 columns instead of 3)
#     Line #577 (got 2 columns instead of 3)
#     Line #578 (got 2 columns instead of 3)
#     Line #579 (got 2 columns instead of 3)
#     Line #580 (got 2 columns instead of 3)
#     Line #581 (got 2 columns instead of 3)
#     Line #582 (got 2 columns instead of 3)
#     Line #583 (got 2 columns instead of 3)
#     Line #584 (got 2 columns instead of 3)
#     Line #585 (got 2 columns instead of 3)
#     Line #586 (got 2 columns instead of 3)
#     Line #587 (got 2 columns instead of 3)
#     Line #588 (got 2 columns instead of 3)
#     Line #589 (got 2 columns instead of 3)
#     Line #590 (got 2 columns instead of 3)
#     Line #591 (got 2 columns instead of 3)
#     Line #592 (got 2 columns instead of 3)
#     Line #593 (got 2 columns instead of 3)
#     Line #594 (got 2 columns instead of 3)
#     Line #595 (got 2 columns instead of 3)
#     Line #596 (got 2 columns instead of 3)
#     Line #597 (got 2 columns instead of 3)
#     Line #598 (got 2 columns instead of 3)
#     Line #599 (got 2 columns instead of 3)
#     Line #600 (got 2 columns instead of 3)
#     Line #601 (got 2 columns instead of 3)
#     Line #602 (got 2 columns instead of 3)
#     Line #603 (got 2 columns instead of 3)
#     Line #604 (got 2 columns instead of 3)
#     Line #605 (got 2 columns instead of 3)
#     Line #606 (got 2 columns instead of 3)
#     Line #607 (got 2 columns instead of 3)
#     Line #608 (got 2 columns instead of 3)
#     Line #609 (got 2 columns instead of 3)
#     Line #610 (got 2 columns instead of 3)
#     Line #611 (got 2 columns instead of 3)
#     Line #612 (got 2 columns instead of 3)
#     Line #613 (got 2 columns instead of 3)
#     Line #614 (got 2 columns instead of 3)
#     Line #615 (got 2 columns instead of 3)
#     Line #616 (got 2 columns instead of 3)
#     Line #617 (got 2 columns instead of 3)
#     Line #618 (got 2 columns instead of 3)
#     Line #619 (got 2 columns instead of 3)
#     Line #620 (got 2 columns instead of 3)
#     Line #621 (got 2 columns instead of 3)
#     Line #622 (got 2 columns instead of 3)
#     Line #623 (got 2 columns instead of 3)
#     Line #624 (got 2 columns instead of 3)
#     Line #625 (got 2 columns instead of 3)
#     Line #626 (got 2 columns instead of 3)
#     Line #627 (got 2 columns instead of 3)
#     Line #628 (got 2 columns instead of 3)
#     Line #629 (got 2 columns instead of 3)
#     Line #630 (got 2 columns instead of 3)
#     Line #631 (got 2 columns instead of 3)
#     Line #632 (got 2 columns instead of 3)
#     Line #633 (got 2 columns instead of 3)
#     Line #634 (got 2 columns instead of 3)
#     Line #635 (got 2 columns instead of 3)
#     Line #636 (got 2 columns instead of 3)
#     Line #637 (got 2 columns instead of 3)
#     Line #638 (got 2 columns instead of 3)
#     Line #639 (got 2 columns instead of 3)
#     Line #640 (got 2 columns instead of 3)
#     Line #641 (got 2 columns instead of 3)
#     Line #642 (got 2 columns instead of 3)
#     Line #643 (got 2 columns instead of 3)
#     Line #644 (got 2 columns instead of 3)
#     Line #645 (got 2 columns instead of 3)
#     Line #646 (got 2 columns instead of 3)
#     Line #647 (got 2 columns instead of 3)
#     Line #648 (got 2 columns instead of 3)
#     Line #649 (got 2 columns instead of 3)
#     Line #650 (got 2 columns instead of 3)
#     Line #651 (got 2 columns instead of 3)
#     Line #652 (got 2 columns instead of 3)
#     Line #653 (got 2 columns instead of 3)
#     Line #654 (got 2 columns instead of 3)
#     Line #655 (got 2 columns instead of 3)
#     Line #656 (got 2 columns instead of 3)
#     Line #657 (got 2 columns instead of 3)
#     Line #658 (got 2 columns instead of 3)
#     Line #659 (got 2 columns instead of 3)
#     Line #660 (got 2 columns instead of 3)
#     Line #661 (got 2 columns instead of 3)
#     Line #662 (got 2 columns instead of 3)
#     Line #663 (got 2 columns instead of 3)
#     Line #664 (got 2 columns instead of 3)
#     Line #665 (got 2 columns instead of 3)
#     Line #666 (got 2 columns instead of 3)
#     Line #667 (got 2 columns instead of 3)
#     Line #668 (got 2 columns instead of 3)
#     Line #669 (got 2 columns instead of 3)
#     Line #670 (got 2 columns instead of 3)
#     Line #671 (got 2 columns instead of 3)
#     Line #672 (got 2 columns instead of 3)
#     Line #673 (got 2 columns instead of 3)
#     Line #674 (got 2 columns instead of 3)
#     Line #675 (got 2 columns instead of 3)
#     Line #676 (got 2 columns instead of 3)
#     Line #677 (got 2 columns instead of 3)
#     Line #678 (got 2 columns instead of 3)
#     Line #679 (got 2 columns instead of 3)
#     Line #680 (got 2 columns instead of 3)
#     Line #681 (got 2 columns instead of 3)
#     Line #682 (got 2 columns instead of 3)
#     Line #683 (got 2 columns instead of 3)
#     Line #684 (got 2 columns instead of 3)
#     Line #685 (got 2 columns instead of 3)
#     Line #686 (got 2 columns instead of 3)
#     Line #687 (got 2 columns instead of 3)
#     Line #688 (got 2 columns instead of 3)
#     Line #689 (got 2 columns instead of 3)
#     Line #690 (got 2 columns instead of 3)
#     Line #691 (got 2 columns instead of 3)
#     Line #692 (got 2 columns instead of 3)
#     Line #693 (got 2 columns instead of 3)
#     Line #694 (got 2 columns instead of 3)
#     Line #695 (got 2 columns instead of 3)
#     Line #696 (got 2 columns instead of 3)
#     Line #697 (got 2 columns instead of 3)
#     Line #698 (got 2 columns instead of 3)
#     Line #699 (got 2 columns instead of 3)
#     Line #700 (got 2 columns instead of 3)
#     Line #701 (got 2 columns instead of 3)
#     Line #702 (got 2 columns instead of 3)
#     Line #703 (got 2 columns instead of 3)
#     Line #704 (got 2 columns instead of 3)
#     Line #705 (got 2 columns instead of 3)
#     Line #706 (got 2 columns instead of 3)
#     Line #707 (got 2 columns instead of 3)
#     Line #708 (got 2 columns instead of 3)
#     Line #709 (got 2 columns instead of 3)
#     Line #710 (got 2 columns instead of 3)
#     Line #711 (got 2 columns instead of 3)
#     Line #712 (got 2 columns instead of 3)
#     Line #713 (got 2 columns instead of 3)
#     Line #714 (got 2 columns instead of 3)
#     Line #715 (got 2 columns instead of 3)
#     Line #716 (got 2 columns instead of 3)
#     Line #717 (got 2 columns instead of 3)
#     Line #718 (got 2 columns instead of 3)
#     Line #719 (got 2 columns instead of 3)
#     Line #720 (got 2 columns instead of 3)
#     Line #721 (got 2 columns instead of 3)
#     Line #722 (got 2 columns instead of 3)
#     Line #723 (got 2 columns instead of 3)
#     Line #724 (got 2 columns instead of 3)
#     Line #725 (got 2 columns instead of 3)
#     Line #726 (got 2 columns instead of 3)
#     Line #727 (got 2 columns instead of 3)
#     Line #728 (got 2 columns instead of 3)
#     Line #729 (got 2 columns instead of 3)
#     Line #730 (got 2 columns instead of 3)
#     Line #731 (got 2 columns instead of 3)
#     Line #732 (got 2 columns instead of 3)
#     Line #733 (got 2 columns instead of 3)
#     Line #734 (got 2 columns instead of 3)
#     Line #735 (got 2 columns instead of 3)
#     Line #736 (got 2 columns instead of 3)
#     Line #737 (got 2 columns instead of 3)
#     Line #738 (got 2 columns instead of 3)
#     Line #739 (got 2 columns instead of 3)
#     Line #740 (got 2 columns instead of 3)
#     Line #741 (got 2 columns instead of 3)
#     Line #742 (got 2 columns instead of 3)
#     Line #743 (got 2 columns instead of 3)
#     Line #744 (got 2 columns instead of 3)
#     Line #745 (got 2 columns instead of 3)
#     Line #746 (got 2 columns instead of 3)
#     Line #747 (got 2 columns instead of 3)
#     Line #748 (got 2 columns instead of 3)
#     Line #749 (got 2 columns instead of 3)
#     Line #750 (got 2 columns instead of 3)
#     Line #751 (got 2 columns instead of 3)
#     Line #752 (got 2 columns instead of 3)
#     Line #753 (got 2 columns instead of 3)
#     Line #754 (got 2 columns instead of 3)
#     Line #755 (got 2 columns instead of 3)
#     Line #756 (got 2 columns instead of 3)
#     Line #757 (got 2 columns instead of 3)
#     Line #758 (got 2 columns instead of 3)
#     Line #759 (got 2 columns instead of 3)
#     Line #760 (got 2 columns instead of 3)
#     Line #761 (got 2 columns instead of 3)
#     Line #762 (got 2 columns instead of 3)
#     Line #763 (got 2 columns instead of 3)
#     Line #764 (got 2 columns instead of 3)
#     Line #765 (got 2 columns instead of 3)
#     Line #766 (got 2 columns instead of 3)
#     Line #767 (got 2 columns instead of 3)
#     Line #768 (got 2 columns instead of 3)
#     Line #769 (got 2 columns instead of 3)
#     Line #770 (got 2 columns instead of 3)
#     Line #771 (got 2 columns instead of 3)
#     Line #772 (got 2 columns instead of 3)
#     Line #773 (got 2 columns instead of 3)
#     Line #774 (got 2 columns instead of 3)
#     Line #775 (got 2 columns instead of 3)
#     Line #776 (got 2 columns instead of 3)
#     Line #777 (got 2 columns instead of 3)
#     Line #778 (got 2 columns instead of 3)
#     Line #779 (got 2 columns instead of 3)
#     Line #780 (got 2 columns instead of 3)
#     Line #781 (got 2 columns instead of 3)
#     Line #782 (got 2 columns instead of 3)
#     Line #783 (got 2 columns instead of 3)
#     Line #784 (got 2 columns instead of 3)
#     Line #785 (got 2 columns instead of 3)
#     Line #786 (got 2 columns instead of 3)
#     Line #787 (got 2 columns instead of 3)
#     Line #788 (got 2 columns instead of 3)
#     Line #789 (got 2 columns instead of 3)
#     Line #790 (got 2 columns instead of 3)
#     Line #791 (got 2 columns instead of 3)
#     Line #792 (got 2 columns instead of 3)
#     Line #793 (got 2 columns instead of 3)
#     Line #794 (got 2 columns instead of 3)
#     Line #795 (got 2 columns instead of 3)
#     Line #796 (got 2 columns instead of 3)
#     Line #797 (got 2 columns instead of 3)
#     Line #798 (got 2 columns instead of 3)
#     Line #799 (got 2 columns instead of 3)
#     Line #800 (got 2 columns instead of 3)
#     Line #801 (got 2 columns instead of 3)
#     Line #802 (got 2 columns instead of 3)
#     Line #803 (got 2 columns instead of 3)
#     Line #804 (got 2 columns instead of 3)
#     Line #805 (got 2 columns instead of 3)
#     Line #806 (got 2 columns instead of 3)
#     Line #807 (got 2 columns instead of 3)
#     Line #808 (got 2 columns instead of 3)
#     Line #809 (got 2 columns instead of 3)
#     Line #810 (got 2 columns instead of 3)
#     Line #811 (got 2 columns instead of 3)
#     Line #812 (got 2 columns instead of 3)
#     Line #813 (got 2 columns instead of 3)
#     Line #814 (got 2 columns instead of 3)
#     Line #815 (got 2 columns instead of 3)
#     Line #816 (got 2 columns instead of 3)
#     Line #817 (got 2 columns instead of 3)
#     Line #818 (got 2 columns instead of 3)
#     Line #819 (got 2 columns instead of 3)
#     Line #820 (got 2 columns instead of 3)
#     Line #821 (got 2 columns instead of 3)
#     Line #822 (got 2 columns instead of 3)
#     Line #823 (got 2 columns instead of 3)
#     Line #824 (got 2 columns instead of 3)
#     Line #825 (got 2 columns instead of 3)
#     Line #826 (got 2 columns instead of 3)
#     Line #827 (got 2 columns instead of 3)
#     Line #828 (got 2 columns instead of 3)
#     Line #829 (got 2 columns instead of 3)
#     Line #830 (got 2 columns instead of 3)
#     Line #831 (got 2 columns instead of 3)
#     Line #832 (got 2 columns instead of 3)
#     Line #833 (got 2 columns instead of 3)
#     Line #834 (got 2 columns instead of 3)
#     Line #835 (got 2 columns instead of 3)
#     Line #836 (got 2 columns instead of 3)
#     Line #837 (got 2 columns instead of 3)
#     Line #838 (got 2 columns instead of 3)
#     Line #839 (got 2 columns instead of 3)
#     Line #840 (got 2 columns instead of 3)
#     Line #841 (got 2 columns instead of 3)
#     Line #842 (got 2 columns instead of 3)
#     Line #843 (got 2 columns instead of 3)
#     Line #844 (got 2 columns instead of 3)
#     Line #845 (got 2 columns instead of 3)
#     Line #846 (got 2 columns instead of 3)
#     Line #847 (got 2 columns instead of 3)
#     Line #848 (got 2 columns instead of 3)
#     Line #849 (got 2 columns instead of 3)
#     Line #850 (got 2 columns instead of 3)
#     Line #851 (got 2 columns instead of 3)
#     Line #852 (got 2 columns instead of 3)
#     Line #853 (got 2 columns instead of 3)
#     Line #854 (got 2 columns instead of 3)
#     Line #855 (got 2 columns instead of 3)
#     Line #856 (got 2 columns instead of 3)
#     Line #857 (got 2 columns instead of 3)
#     Line #858 (got 2 columns instead of 3)
#     Line #859 (got 2 columns instead of 3)
#     Line #860 (got 2 columns instead of 3)
#     Line #861 (got 2 columns instead of 3)
#     Line #862 (got 2 columns instead of 3)
#     Line #863 (got 2 columns instead of 3)
#     Line #864 (got 2 columns instead of 3)
#     Line #865 (got 2 columns instead of 3)
#     Line #866 (got 2 columns instead of 3)
#     Line #867 (got 2 columns instead of 3)
#     Line #868 (got 2 columns instead of 3)
#     Line #869 (got 2 columns instead of 3)
#     Line #870 (got 2 columns instead of 3)
#     Line #871 (got 2 columns instead of 3)
#     Line #872 (got 2 columns instead of 3)
#     Line #873 (got 2 columns instead of 3)
#     Line #874 (got 2 columns instead of 3)
#     Line #875 (got 2 columns instead of 3)
#     Line #876 (got 2 columns instead of 3)
#     Line #877 (got 2 columns instead of 3)
#     Line #878 (got 2 columns instead of 3)
#     Line #879 (got 2 columns instead of 3)
#     Line #880 (got 2 columns instead of 3)
#     Line #881 (got 2 columns instead of 3)
#     Line #882 (got 2 columns instead of 3)
#     Line #883 (got 2 columns instead of 3)
#     Line #884 (got 2 columns instead of 3)
#     Line #885 (got 2 columns instead of 3)
#     Line #886 (got 2 columns instead of 3)
#     Line #887 (got 2 columns instead of 3)
#     Line #888 (got 2 columns instead of 3)
#     Line #889 (got 2 columns instead of 3)
#     Line #890 (got 2 columns instead of 3)
#     Line #891 (got 2 columns instead of 3)
#     Line #892 (got 2 columns instead of 3)
#     Line #893 (got 2 columns instead of 3)
#     Line #894 (got 2 columns instead of 3)
#     Line #895 (got 2 columns instead of 3)
#     Line #896 (got 2 columns instead of 3)
#     Line #897 (got 2 columns instead of 3)
#     Line #898 (got 2 columns instead of 3)
#     Line #899 (got 2 columns instead of 3)
#     Line #900 (got 2 columns instead of 3)
#     Line #901 (got 2 columns instead of 3)
#     Line #902 (got 2 columns instead of 3)
#     Line #903 (got 2 columns instead of 3)
#     Line #904 (got 2 columns instead of 3)
#     Line #905 (got 2 columns instead of 3)
#     Line #906 (got 2 columns instead of 3)
#     Line #907 (got 2 columns instead of 3)
#     Line #908 (got 2 columns instead of 3)
#     Line #909 (got 2 columns instead of 3)
#     Line #910 (got 2 columns instead of 3)
#     Line #911 (got 2 columns instead of 3)
#     Line #912 (got 2 columns instead of 3)
#     Line #913 (got 2 columns instead of 3)
#     Line #914 (got 2 columns instead of 3)
#     Line #915 (got 2 columns instead of 3)
#     Line #916 (got 2 columns instead of 3)
#     Line #917 (got 2 columns instead of 3)
#     Line #918 (got 2 columns instead of 3)
#     Line #919 (got 2 columns instead of 3)
#     Line #920 (got 2 columns instead of 3)
#     Line #921 (got 2 columns instead of 3)
#     Line #922 (got 2 columns instead of 3)
#     Line #923 (got 2 columns instead of 3)
#     Line #924 (got 2 columns instead of 3)
#     Line #925 (got 2 columns instead of 3)
#     Line #926 (got 2 columns instead of 3)
#     Line #927 (got 2 columns instead of 3)
#     Line #928 (got 2 columns instead of 3)
#     Line #929 (got 2 columns instead of 3)
#     Line #930 (got 2 columns instead of 3)
#     Line #931 (got 2 columns instead of 3)
#     Line #932 (got 2 columns instead of 3)
#     Line #933 (got 2 columns instead of 3)
#     Line #934 (got 2 columns instead of 3)
#     Line #935 (got 2 columns instead of 3)
#     Line #936 (got 2 columns instead of 3)
#     Line #937 (got 2 columns instead of 3)
#     Line #938 (got 2 columns instead of 3)
#     Line #939 (got 2 columns instead of 3)
#     Line #940 (got 2 columns instead of 3)
#     Line #941 (got 2 columns instead of 3)
#     Line #942 (got 2 columns instead of 3)
#     Line #943 (got 2 columns instead of 3)
#     Line #944 (got 2 columns instead of 3)
#     Line #945 (got 2 columns instead of 3)
#     Line #946 (got 2 columns instead of 3)
#     Line #947 (got 2 columns instead of 3)
#     Line #948 (got 2 columns instead of 3)
#     Line #949 (got 2 columns instead of 3)
#     Line #950 (got 2 columns instead of 3)
#     Line #951 (got 2 columns instead of 3)
#     Line #952 (got 2 columns instead of 3)
#     Line #953 (got 2 columns instead of 3)
#     Line #954 (got 2 columns instead of 3)
#     Line #955 (got 2 columns instead of 3)
#     Line #956 (got 2 columns instead of 3)
#     Line #957 (got 2 columns instead of 3)
#     Line #958 (got 2 columns instead of 3)
#     Line #959 (got 2 columns instead of 3)
#     Line #960 (got 2 columns instead of 3)
#     Line #961 (got 2 columns instead of 3)
#     Line #962 (got 2 columns instead of 3)
#     Line #963 (got 2 columns instead of 3)
#     Line #964 (got 2 columns instead of 3)
#     Line #965 (got 2 columns instead of 3)
#     Line #966 (got 2 columns instead of 3)
#     Line #967 (got 2 columns instead of 3)
#     Line #968 (got 2 columns instead of 3)
#     Line #969 (got 2 columns instead of 3)
#     Line #970 (got 2 columns instead of 3)
#     Line #971 (got 2 columns instead of 3)
#     Line #972 (got 2 columns instead of 3)
#     Line #973 (got 2 columns instead of 3)
#     Line #974 (got 2 columns instead of 3)
#     Line #975 (got 2 columns instead of 3)
#     Line #976 (got 2 columns instead of 3)
#     Line #977 (got 2 columns instead of 3)
#     Line #978 (got 2 columns instead of 3)
#     Line #979 (got 2 columns instead of 3)
#     Line #980 (got 2 columns instead of 3)
#     Line #981 (got 2 columns instead of 3)
#     Line #982 (got 2 columns instead of 3)
#     Line #983 (got 2 columns instead of 3)
#     Line #984 (got 2 columns instead of 3)
#     Line #985 (got 2 columns instead of 3)
#     Line #986 (got 2 columns instead of 3)
#     Line #987 (got 2 columns instead of 3)
#     Line #988 (got 2 columns instead of 3)
#     Line #989 (got 2 columns instead of 3)
#     Line #990 (got 2 columns instead of 3)
#     Line #991 (got 2 columns instead of 3)
#     Line #992 (got 2 columns instead of 3)
#     Line #993 (got 2 columns instead of 3)
#     Line #994 (got 2 columns instead of 3)
#     Line #995 (got 2 columns instead of 3)
#     Line #996 (got 2 columns instead of 3)
#     Line #997 (got 2 columns instead of 3)
#     Line #998 (got 2 columns instead of 3)
#     Line #999 (got 2 columns instead of 3)
#     Line #1000 (got 2 columns instead of 3)
#     Line #1001 (got 2 columns instead of 3)
#     Line #1002 (got 2 columns instead of 3)
#     Line #1003 (got 2 columns instead of 3)
#     Line #1004 (got 2 columns instead of 3)
#     Line #1005 (got 2 columns instead of 3)
#     Line #1006 (got 2 columns instead of 3)
#     Line #1007 (got 2 columns instead of 3)
#     Line #1008 (got 2 columns instead of 3)
#     Line #1009 (got 2 columns instead of 3)
#     Line #1010 (got 2 columns instead of 3)
#     Line #1011 (got 2 columns instead of 3)
#     Line #1012 (got 2 columns instead of 3)
#     Line #1013 (got 2 columns instead of 3)
#     Line #1014 (got 2 columns instead of 3)
#     Line #1015 (got 2 columns instead of 3)
#     Line #1016 (got 2 columns instead of 3)
#     Line #1017 (got 2 columns instead of 3)
#     Line #1018 (got 2 columns instead of 3)
#     Line #1019 (got 2 columns instead of 3)
#     Line #1020 (got 2 columns instead of 3)
#     Line #1021 (got 2 columns instead of 3)
#     Line #1022 (got 2 columns instead of 3)
#     Line #1023 (got 2 columns instead of 3)
#     Line #1024 (got 2 columns instead of 3)
#     Line #1025 (got 2 columns instead of 3)
#     Line #1026 (got 2 columns instead of 3)
#     Line #1027 (got 2 columns instead of 3)
#     Line #1028 (got 2 columns instead of 3)
#     Line #1029 (got 2 columns instead of 3)
#     Line #1030 (got 2 columns instead of 3)
#     Line #1031 (got 2 columns instead of 3)
#     Line #1032 (got 2 columns instead of 3)
#     Line #1033 (got 2 columns instead of 3)
#     Line #1034 (got 2 columns instead of 3)
#     Line #1035 (got 2 columns instead of 3)
#     Line #1036 (got 2 columns instead of 3)
#     Line #1037 (got 2 columns instead of 3)
#     Line #1038 (got 2 columns instead of 3)
#     Line #1039 (got 2 columns instead of 3)
#     Line #1040 (got 2 columns instead of 3)
#     Line #1041 (got 2 columns instead of 3)
#     Line #1042 (got 2 columns instead of 3)
#     Line #1043 (got 2 columns instead of 3)
#     Line #1044 (got 2 columns instead of 3)
#     Line #1045 (got 2 columns instead of 3)
#     Line #1046 (got 2 columns instead of 3)
#     Line #1047 (got 2 columns instead of 3)
#     Line #1048 (got 2 columns instead of 3)
#     Line #1049 (got 2 columns instead of 3)
#     Line #1050 (got 2 columns instead of 3)
#     Line #1051 (got 2 columns instead of 3)
#     Line #1052 (got 2 columns instead of 3)
#     Line #1053 (got 2 columns instead of 3)
#     Line #1054 (got 2 columns instead of 3)
#     Line #1055 (got 2 columns instead of 3)
#     Line #1056 (got 2 columns instead of 3)
#     Line #1057 (got 2 columns instead of 3)
#     Line #1058 (got 2 columns instead of 3)
#     Line #1059 (got 2 columns instead of 3)
#     Line #1060 (got 2 columns instead of 3)
#     Line #1061 (got 2 columns instead of 3)
#     Line #1062 (got 2 columns instead of 3)
#     Line #1063 (got 2 columns instead of 3)
#     Line #1064 (got 2 columns instead of 3)
#     Line #1065 (got 2 columns instead of 3)
#     Line #1066 (got 2 columns instead of 3)
#     Line #1067 (got 2 columns instead of 3)
#     Line #1068 (got 2 columns instead of 3)
#     Line #1069 (got 2 columns instead of 3)
#     Line #1070 (got 2 columns instead of 3)
#     Line #1071 (got 2 columns instead of 3)
#     Line #1072 (got 2 columns instead of 3)
#     Line #1073 (got 2 columns instead of 3)
#     Line #1074 (got 2 columns instead of 3)
#     Line #1075 (got 2 columns instead of 3)
#     Line #1076 (got 2 columns instead of 3)
#     Line #1077 (got 2 columns instead of 3)
#     Line #1078 (got 2 columns instead of 3)
#     Line #1079 (got 2 columns instead of 3)
#     Line #1080 (got 2 columns instead of 3)
#     Line #1081 (got 2 columns instead of 3)
#     Line #1082 (got 2 columns instead of 3)
#     Line #1083 (got 2 columns instead of 3)
#     Line #1084 (got 2 columns instead of 3)
#     Line #1085 (got 2 columns instead of 3)
#     Line #1086 (got 2 columns instead of 3)
#     Line #1087 (got 2 columns instead of 3)
#     Line #1088 (got 2 columns instead of 3)
#     Line #1089 (got 2 columns instead of 3)
#     Line #1090 (got 2 columns instead of 3)
#     Line #1091 (got 2 columns instead of 3)
#     Line #1092 (got 2 columns instead of 3)
#     Line #1093 (got 2 columns instead of 3)
#     Line #1094 (got 2 columns instead of 3)
#     Line #1095 (got 2 columns instead of 3)
#     Line #1096 (got 2 columns instead of 3)
#     Line #1097 (got 2 columns instead of 3)
#     Line #1098 (got 2 columns instead of 3)
#     Line #1099 (got 2 columns instead of 3)
#     Line #1100 (got 2 columns instead of 3)
#     Line #1101 (got 2 columns instead of 3)
#     Line #1102 (got 2 columns instead of 3)
#     Line #1103 (got 2 columns instead of 3)
#     Line #1104 (got 2 columns instead of 3)
#     Line #1105 (got 2 columns instead of 3)
#     Line #1106 (got 2 columns instead of 3)
#     Line #1107 (got 2 columns instead of 3)
#     Line #1108 (got 2 columns instead of 3)
#     Line #1109 (got 2 columns instead of 3)
#     Line #1110 (got 2 columns instead of 3)
#     Line #1111 (got 2 columns instead of 3)
#     Line #1112 (got 2 columns instead of 3)
#     Line #1113 (got 2 columns instead of 3)
# ...
#     Line #2607 (got 2 columns instead of 3)
#     Line #2608 (got 2 columns instead of 3)
#     Line #2609 (got 2 columns instead of 3)
#     Line #2610 (got 2 columns instead of 3)
#     Line #2611 (got 2 columns instead of 3)
#     Line #2612 (got 2 columns instead of 3)
#     Line #2613 (got 2 columns instead of 3)
#     Line #2614 (got 2 columns instead of 3)
#     Line #2615 (got 2 columns instead of 3)
#     Line #2616 (got 2 columns instead of 3)
#     Line #2617 (got 2 columns instead of 3)
#     Line #2618 (got 2 columns instead of 3)
#     Line #2619 (got 2 columns instead of 3)
#     Line #2620 (got 2 columns instead of 3)
#     Line #2621 (got 2 columns instead of 3)
#     Line #2622 (got 2 columns instead of 3)
#     Line #2623 (got 2 columns instead of 3)
#     Line #2624 (got 2 columns instead of 3)
#     Line #2625 (got 2 columns instead of 3)
#     Line #2626 (got 2 columns instead of 3)
#     Line #2627 (got 2 columns instead of 3)
#     Line #2628 (got 2 columns instead of 3)
#     Line #2629 (got 2 columns instead of 3)
#     Line #2630 (got 2 columns instead of 3)
#     Line #2631 (got 2 columns instead of 3)
#     Line #2632 (got 2 columns instead of 3)
#     Line #2633 (got 2 columns instead of 3)
#     Line #2634 (got 2 columns instead of 3)
#     Line #2635 (got 2 columns instead of 3)
#     Line #2636 (got 2 columns instead of 3)
#     Line #2637 (got 2 columns instead of 3)
#     Line #2638 (got 2 columns instead of 3)
#     Line #2639 (got 2 columns instead of 3)
#     Line #2640 (got 2 columns instead of 3)
#     Line #2641 (got 2 columns instead of 3)
#     Line #2642 (got 2 columns instead of 3)
#     Line #2643 (got 2 columns instead of 3)
#     Line #2644 (got 2 columns instead of 3)
#     Line #2645 (got 2 columns instead of 3)
#     Line #2646 (got 2 columns instead of 3)
#     Line #2647 (got 2 columns instead of 3)
#     Line #2648 (got 2 columns instead of 3)
#     Line #2649 (got 2 columns instead of 3)
#     Line #2650 (got 2 columns instead of 3)
#     Line #2651 (got 2 columns instead of 3)
#     Line #2652 (got 2 columns instead of 3)
#     Line #2653 (got 2 columns instead of 3)
#     Line #2654 (got 2 columns instead of 3)
#     Line #2655 (got 2 columns instead of 3)
#     Line #2656 (got 2 columns instead of 3)
#     Line #2657 (got 2 columns instead of 3)
#     Line #2658 (got 2 columns instead of 3)
#     Line #2659 (got 2 columns instead of 3)
#     Line #2660 (got 2 columns instead of 3)
#     Line #2661 (got 2 columns instead of 3)
#     Line #2662 (got 2 columns instead of 3)
#     Line #2663 (got 2 columns instead of 3)
#     Line #2664 (got 2 columns instead of 3)
#     Line #2665 (got 2 columns instead of 3)
#     Line #2666 (got 2 columns instead of 3)
#     Line #2667 (got 2 columns instead of 3)
#     Line #2668 (got 2 columns instead of 3)
#     Line #2669 (got 2 columns instead of 3)
#     Line #2670 (got 2 columns instead of 3)
#     Line #2671 (got 2 columns instead of 3)
#     Line #2672 (got 2 columns instead of 3)
#     Line #2673 (got 2 columns instead of 3)
#     Line #2674 (got 2 columns instead of 3)
#     Line #2675 (got 2 columns instead of 3)
#     Line #2676 (got 2 columns instead of 3)
#     Line #2677 (got 2 columns instead of 3)
#     Line #2678 (got 2 columns instead of 3)
#     Line #2679 (got 2 columns instead of 3)
#     Line #2680 (got 2 columns instead of 3)
#     Line #2681 (got 2 columns instead of 3)
#     Line #2682 (got 2 columns instead of 3)
#     Line #2683 (got 2 columns instead of 3)
#     Line #2684 (got 2 columns instead of 3)
#     Line #2685 (got 2 columns instead of 3)
#     Line #2686 (got 2 columns instead of 3)
#     Line #2687 (got 2 columns instead of 3)
#     Line #2688 (got 2 columns instead of 3)
#     Line #2689 (got 2 columns instead of 3)
#     Line #2690 (got 2 columns instead of 3)
#     Line #2691 (got 2 columns instead of 3)
#     Line #2692 (got 2 columns instead of 3)
#     Line #2693 (got 2 columns instead of 3)
#     Line #2694 (got 2 columns instead of 3)
#     Line #2695 (got 2 columns instead of 3)
#     Line #2696 (got 2 columns instead of 3)
#     Line #2697 (got 2 columns instead of 3)
#     Line #2698 (got 2 columns instead of 3)
#     Line #2699 (got 2 columns instead of 3)
#     Line #2700 (got 2 columns instead of 3)
#     Line #2701 (got 2 columns instead of 3)
#     Line #2702 (got 2 columns instead of 3)
#     Line #2703 (got 2 columns instead of 3)
#     Line #2704 (got 2 columns instead of 3)
#     Line #2705 (got 2 columns instead of 3)
#     Line #2706 (got 2 columns instead of 3)
#     Line #2707 (got 2 columns instead of 3)
#     Line #2708 (got 2 columns instead of 3)
#     Line #2709 (got 2 columns instead of 3)
#     Line #2710 (got 2 columns instead of 3)
#     Line #2711 (got 2 columns instead of 3)
#     Line #2712 (got 2 columns instead of 3)
#     Line #2713 (got 2 columns instead of 3)
#     Line #2714 (got 2 columns instead of 3)
#     Line #2715 (got 2 columns instead of 3)
#     Line #2716 (got 2 columns instead of 3)
#     Line #2717 (got 2 columns instead of 3)
#     Line #2718 (got 2 columns instead of 3)
#     Line #2719 (got 2 columns instead of 3)
#     Line #2720 (got 2 columns instead of 3)
#     Line #2721 (got 2 columns instead of 3)
#     Line #2722 (got 2 columns instead of 3)
#     Line #2723 (got 2 columns instead of 3)
#     Line #2724 (got 2 columns instead of 3)
#     Line #2725 (got 2 columns instead of 3)
#     Line #2726 (got 2 columns instead of 3)
#     Line #2727 (got 2 columns instead of 3)
#     Line #2728 (got 2 columns instead of 3)
#     Line #2729 (got 2 columns instead of 3)
#     Line #2730 (got 2 columns instead of 3)
#     Line #2731 (got 2 columns instead of 3)
#     Line #2732 (got 2 columns instead of 3)
#     Line #2733 (got 2 columns instead of 3)
#     Line #2734 (got 2 columns instead of 3)
#     Line #2735 (got 2 columns instead of 3)
#     Line #2736 (got 2 columns instead of 3)
#     Line #2737 (got 2 columns instead of 3)
#     Line #2738 (got 2 columns instead of 3)
#     Line #2739 (got 2 columns instead of 3)
#     Line #2740 (got 2 columns instead of 3)
#     Line #2741 (got 2 columns instead of 3)
#     Line #2742 (got 2 columns instead of 3)
#     Line #2743 (got 2 columns instead of 3)
#     Line #2744 (got 2 columns instead of 3)
#     Line #2745 (got 2 columns instead of 3)
#     Line #2746 (got 2 columns instead of 3)
#     Line #2747 (got 2 columns instead of 3)
#     Line #2748 (got 2 columns instead of 3)
#     Line #2749 (got 2 columns instead of 3)
#     Line #2750 (got 2 columns instead of 3)
#     Line #2751 (got 2 columns instead of 3)
#     Line #2752 (got 2 columns instead of 3)
#     Line #2753 (got 2 columns instead of 3)
#     Line #2754 (got 2 columns instead of 3)
#     Line #2755 (got 2 columns instead of 3)
#     Line #2756 (got 2 columns instead of 3)
#     Line #2757 (got 2 columns instead of 3)
#     Line #2758 (got 2 columns instead of 3)
#     Line #2759 (got 2 columns instead of 3)
#     Line #2760 (got 2 columns instead of 3)
#     Line #2761 (got 2 columns instead of 3)
#     Line #2762 (got 2 columns instead of 3)
#     Line #2763 (got 2 columns instead of 3)
#     Line #2764 (got 2 columns instead of 3)
#     Line #2765 (got 2 columns instead of 3)
#     Line #2766 (got 2 columns instead of 3)
#     Line #2767 (got 2 columns instead of 3)
#     Line #2768 (got 2 columns instead of 3)
#     Line #2769 (got 2 columns instead of 3)
#     Line #2770 (got 2 columns instead of 3)
#     Line #2771 (got 2 columns instead of 3)
#     Line #2772 (got 2 columns instead of 3)
#     Line #2773 (got 2 columns instead of 3)
#     Line #2774 (got 2 columns instead of 3)
#     Line #2775 (got 2 columns instead of 3)
#     Line #2776 (got 2 columns instead of 3)
#     Line #2777 (got 2 columns instead of 3)
#     Line #2778 (got 2 columns instead of 3)
#     Line #2779 (got 2 columns instead of 3)
#     Line #2780 (got 2 columns instead of 3)
#     Line #2781 (got 2 columns instead of 3)
#     Line #2782 (got 2 columns instead of 3)
#     Line #2783 (got 2 columns instead of 3)
#     Line #2784 (got 2 columns instead of 3)
#     Line #2785 (got 2 columns instead of 3)
#     Line #2786 (got 2 columns instead of 3)
#     Line #2787 (got 2 columns instead of 3)
#     Line #2788 (got 2 columns instead of 3)
#     Line #2789 (got 2 columns instead of 3)
#     Line #2790 (got 2 columns instead of 3)
#     Line #2791 (got 2 columns instead of 3)
#     Line #2792 (got 2 columns instead of 3)
#     Line #2793 (got 2 columns instead of 3)
#     Line #2794 (got 2 columns instead of 3)
#     Line #2795 (got 2 columns instead of 3)
#     Line #2796 (got 2 columns instead of 3)
#     Line #2797 (got 2 columns instead of 3)
#     Line #2798 (got 2 columns instead of 3)
#     Line #2799 (got 2 columns instead of 3)
#     Line #2800 (got 2 columns instead of 3)
#     Line #2801 (got 2 columns instead of 3)
#     Line #2802 (got 2 columns instead of 3)
#     Line #2803 (got 2 columns instead of 3)
#     Line #2804 (got 2 columns instead of 3)
#     Line #2805 (got 2 columns instead of 3)
#     Line #2806 (got 2 columns instead of 3)
#     Line #2807 (got 2 columns instead of 3)
#     Line #2808 (got 2 columns instead of 3)
#     Line #2809 (got 2 columns instead of 3)
#     Line #2810 (got 2 columns instead of 3)
#     Line #2811 (got 2 columns instead of 3)
#     Line #2812 (got 2 columns instead of 3)
#     Line #2813 (got 2 columns instead of 3)
#     Line #2814 (got 2 columns instead of 3)
#     Line #2815 (got 2 columns instead of 3)
#     Line #2816 (got 2 columns instead of 3)
#     Line #2817 (got 2 columns instead of 3)
#     Line #2818 (got 2 columns instead of 3)
#     Line #2819 (got 2 columns instead of 3)
#     Line #2820 (got 2 columns instead of 3)
#     Line #2821 (got 2 columns instead of 3)
#     Line #2822 (got 2 columns instead of 3)
#     Line #2823 (got 2 columns instead of 3)
#     Line #2824 (got 2 columns instead of 3)
#     Line #2825 (got 2 columns instead of 3)
#     Line #2826 (got 2 columns instead of 3)
#     Line #2827 (got 2 columns instead of 3)
#     Line #2828 (got 2 columns instead of 3)
#     Line #2829 (got 2 columns instead of 3)
#     Line #2830 (got 2 columns instead of 3)
#     Line #2831 (got 2 columns instead of 3)
#     Line #2832 (got 2 columns instead of 3)
#     Line #2833 (got 2 columns instead of 3)
#     Line #2834 (got 2 columns instead of 3)
#     Line #2835 (got 2 columns instead of 3)
#     Line #2836 (got 2 columns instead of 3)
#     Line #2837 (got 2 columns instead of 3)
#     Line #2838 (got 2 columns instead of 3)
#     Line #2839 (got 2 columns instead of 3)
#     Line #2840 (got 2 columns instead of 3)
#     Line #2841 (got 2 columns instead of 3)
#     Line #2842 (got 2 columns instead of 3)
#     Line #2843 (got 2 columns instead of 3)
#     Line #2844 (got 2 columns instead of 3)
#     Line #2845 (got 2 columns instead of 3)
#     Line #2846 (got 2 columns instead of 3)
#     Line #2847 (got 2 columns instead of 3)
#     Line #2848 (got 2 columns instead of 3)
#     Line #2849 (got 2 columns instead of 3)
#     Line #2850 (got 2 columns instead of 3)
#     Line #2851 (got 2 columns instead of 3)
#     Line #2852 (got 2 columns instead of 3)
#     Line #2853 (got 2 columns instead of 3)
#     Line #2854 (got 2 columns instead of 3)
#     Line #2855 (got 2 columns instead of 3)
#     Line #2856 (got 2 columns instead of 3)
#     Line #2857 (got 2 columns instead of 3)
#     Line #2858 (got 2 columns instead of 3)
#     Line #2859 (got 2 columns instead of 3)
#     Line #2860 (got 2 columns instead of 3)
#     Line #2861 (got 2 columns instead of 3)
#     Line #2862 (got 2 columns instead of 3)
#     Line #2863 (got 2 columns instead of 3)
#     Line #2864 (got 2 columns instead of 3)
#     Line #2865 (got 2 columns instead of 3)
#     Line #2866 (got 2 columns instead of 3)
#     Line #2867 (got 2 columns instead of 3)
#     Line #2868 (got 2 columns instead of 3)
#     Line #2869 (got 2 columns instead of 3)
#     Line #2870 (got 2 columns instead of 3)
#     Line #2871 (got 2 columns instead of 3)
#     Line #2872 (got 2 columns instead of 3)
#     Line #2873 (got 2 columns instead of 3)
#     Line #2874 (got 2 columns instead of 3)
#     Line #2875 (got 2 columns instead of 3)
#     Line #2876 (got 2 columns instead of 3)
#     Line #2877 (got 2 columns instead of 3)
#     Line #2878 (got 2 columns instead of 3)
#     Line #2879 (got 2 columns instead of 3)
#     Line #2880 (got 2 columns instead of 3)
#     Line #2881 (got 2 columns instead of 3)
#     Line #2882 (got 2 columns instead of 3)
#     Line #2883 (got 2 columns instead of 3)
#     Line #2884 (got 2 columns instead of 3)
#     Line #2885 (got 2 columns instead of 3)
#     Line #2886 (got 2 columns instead of 3)
#     Line #2887 (got 2 columns instead of 3)
#     Line #2888 (got 2 columns instead of 3)
#     Line #2889 (got 2 columns instead of 3)
#     Line #2890 (got 2 columns instead of 3)
#     Line #2891 (got 2 columns instead of 3)
#     Line #2892 (got 2 columns instead of 3)
#     Line #2893 (got 2 columns instead of 3)
#     Line #2894 (got 2 columns instead of 3)
#     Line #2895 (got 2 columns instead of 3)
#     Line #2896 (got 2 columns instead of 3)
#     Line #2897 (got 2 columns instead of 3)
#     Line #2898 (got 2 columns instead of 3)
#     Line #2899 (got 2 columns instead of 3)
#     Line #2900 (got 2 columns instead of 3)
#     Line #2901 (got 2 columns instead of 3)
#     Line #2902 (got 2 columns instead of 3)
#     Line #2903 (got 2 columns instead of 3)
#     Line #2904 (got 2 columns instead of 3)
#     Line #2905 (got 2 columns instead of 3)
#   data = np.genfromtxt(io.StringIO(raw), delimiter=',', comments='#',
# C:\Users\user\anaconda3\Lib\site-packages\numpy\core\numeric.py:407: ComplexWarning: Casting complex values to real discards the imaginary part
#   multiarray.copyto(res, fill_value, casting='unsafe')
# Warning: failed to download/parse Kischkat Si3N4 data - using fallback approx.
#  axis 1 is out of bounds for array of dimension 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 79
#      77 eps_air = 1.0
#      78 t_si3n4 = np.array([15e-9])           # fixed thickness 15 nm (shape (1,))
# ---> 79 sample = snompy.Sample(
#      80     eps_stack=(eps_air, eps_si3n4, eps_water) if False else (eps_air, eps_si3n4, 0),
#      81     # NOTE: snompy.Sample expects eps_stack entries to be arrays of length = n_freq or scalars.
#      82     # We must pass eps_si3n4 as an array of length len(nu_vac). However, the 'snompy' object
#      83     # creation below depends on its API. We'll build eps_stack as:
#      84 )
#      86 # --- Build eps_stack correctly according to snompy expectations ---
#      87 # Many versions of snompy accept eps_stack with each layer either
#      88 #  - a scalar (non-dispersive) OR
#      89 #  - an array matching len(nu_vac).
#      90 # We'll ensure eps_si3n4 and eps_water are arrays of length len(nu_vac).
#      91 eps_si3n4_arr = eps_si3n4  # length == len(nu_vac)
#
# File ~\anaconda3\Lib\site-packages\snompy\sample.py:124, in Sample.__init__(self, eps_stack, beta_stack, t_stack, eps_env, nu_vac)
#     122 self.t_stack = t_stack
#     123 if eps_stack is not None:
# --> 124     self.eps_stack = eps_stack
#     125 elif beta_stack is not None:
#     126     self.beta_stack = beta_stack
#
# File ~\anaconda3\Lib\site-packages\snompy\sample.py:152, in Sample.eps_stack(self, val)
#     149 self._eps_stack = np.asanyarray(np.broadcast_arrays(*val), dtype=complex)
#     151 # Check inputs make sense
# --> 152 self._check_layers_valid()
#
# File ~\anaconda3\Lib\site-packages\snompy\sample.py:461, in Sample._check_layers_valid(self)
#     459 if (self.t_stack is not None) and (self.eps_stack is not None):
#     460     if self.eps_stack.shape[0] != self.t_stack.shape[0] + 2:
# --> 461         raise ValueError(
#     462             " ".join(
#     463                 [
#     464                     "Invalid inputs:",
#     465                     "`eps_stack` must be 2 longer than `t_stack`, or",
#     466                     "`beta_stack` must be 1 longer than `t_stack`,",
#     467                     "along the first axis.",
#     468                 ]
#     469             )
#     470         )
#
# ValueError: Invalid inputs: `eps_stack` must be 2 longer than `t_stack`, or `beta_stack` must be 1 longer than `t_stack`, along the first axis.

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# Experimental parameters
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
n = 3
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2
method = "Q_ave"

# Semi-infinite superstrate and substrate
eps_air = 1.0
eps_Si = 11.7  # mid-IR permittivity of Si

# Si3N4 dielectric function (Lorentz-like model for mid-IR absorption)
eps_Si3N4 = snompy.sample.lorentz_perm(
    nu_vac,
    nu_j=900e2,      # main absorption peak ~11 µm
    gamma_j=50e2,    # damping
    A_j=2e8,         # strength
    eps_inf=4.0      # high-frequency permittivity
)

t_Si3N4 = 15e-9  # fixed thickness of Si3N4

# PMMA dielectric function (simplified model)
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = np.geomspace(1, 35, 32) * 1e-9

# Define the 4-layer stack: air / Si3N4 / PMMA / Si
sample_stack = snompy.Sample(
    eps_stack=(eps_air, eps_Si3N4, eps_pmma, eps_Si),
    t_stack=(np.full_like(t_pmma, t_Si3N4)[:, np.newaxis],
             t_pmma[:, np.newaxis]),
    nu_vac=nu_vac,
)

# Gold reference
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# Measurement
alpha_eff_stack = snompy.fdm.eff_pol_n(
    sample=sample_stack, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_stack = sample_stack.refl_coef(theta_in=theta_in)
sigma_stack = (1 + c_r * r_coef_stack) ** 2 * alpha_eff_stack

alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalised complex scattering
eta_n = sigma_stack / sigma_Au

# Plot output
fig, axes = plt.subplots(nrows=2, sharex=True)

nu_per_cm = nu_vac * 1e-2
t_nm = t_pmma * 1e9

SM = plt.cm.ScalarMappable(
    cmap=plt.cm.Spectral_r, norm=Normalize(vmin=t_nm.min(), vmax=t_nm.max())
)

for t, sigma in zip(t_nm, eta_n):
    c = SM.to_rgba(t)
    axes[0].plot(nu_per_cm, np.abs(sigma), c=c)
    axes[1].plot(nu_per_cm, np.angle(sigma), c=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
fig.colorbar(SM, ax=axes, label="PMMA thickness / nm")
plt.show(block=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# -----------------------
# Experimental parameters
# -----------------------
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
n = 3
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # [m^-1] as in your original code (cm^-1 * 1e2)
method = "Q_ave"

# -------------------------------
# Media: air (superstrate) & Si (substrate)
# -------------------------------
eps_air = 1.0
eps_Si = 11.7  # approximate mid-IR permittivity of Si

# -------------------------------------------------------
# PMMA dielectric function (same synthetic Lorentz model)
# -------------------------------------------------------
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2.0
)
t_pmma = np.geomspace(1, 35, 32) * 1e-9  # 1–35 nm

# -------------------------------------------------------
# Graphene monolayer (0.3 nm) via sheet conductivity σ0
# -------------------------------------------------------
# Constants
eps0 = 8.8541878128e-12  # F/m
c0   = 299792458.0       # m/s
e    = 1.602176634e-19   # C
hbar = 1.054571817e-34   # J*s

sigma0 = e**2 / (4*hbar)   # ~6.085e-5 S (universal interband sheet conductivity)
t_g = 0.3e-9               # 0.3 nm monolayer thickness

# Angular frequency omega = 2π * c * k0, with k0 = nu_vac [m^-1]
omega = 2*np.pi * c0 * (nu_vac * 1.0)  # [rad/s]

# Effective bulk permittivity for ultra-thin film:
# eps_g(ω) = 1 + i * sigma_sheet / (eps0 * ω * t_g)
eps_graphene = 1.0 + 1j * sigma0 / (eps0 * omega * t_g)

# -------------------------------------------------------
# Build 4-layer sample: air / graphene / PMMA / Si
# -------------------------------------------------------
sample_stack = snompy.Sample(
    eps_stack=(eps_air, eps_graphene, eps_pmma, eps_Si),
    t_stack=(np.full_like(t_pmma, t_g)[:, np.newaxis],   # fixed graphene thickness
             t_pmma[:, np.newaxis]),                     # varying PMMA thickness
    nu_vac=nu_vac,
)

# --------------------
# Gold reference (Au)
# --------------------
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# --------------------
# Measurement signals
# --------------------
alpha_eff_stack = snompy.fdm.eff_pol_n(
    sample=sample_stack, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_stack = sample_stack.refl_coef(theta_in=theta_in)
sigma_stack = (1 + c_r * r_coef_stack) ** 2 * alpha_eff_stack

alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# -------------------------------
# Normalized complex scattering
# -------------------------------
eta_n = sigma_stack / sigma_Au

# -----------
# Plotting
# -----------
fig, axes = plt.subplots(nrows=2, sharex=True)

nu_per_cm = nu_vac * 1e-2        # for axis labeling (cm^-1)
t_nm = t_pmma * 1e9              # PMMA thickness in nm

SM = plt.cm.ScalarMappable(
    cmap=plt.cm.Spectral_r, norm=Normalize(vmin=t_nm.min(), vmax=t_nm.max())
)

for t, sigma in zip(t_nm, eta_n):
    c = SM.to_rgba(t)
    axes[0].plot(nu_per_cm, np.abs(sigma), c=c)
    axes[1].plot(nu_per_cm, np.angle(sigma), c=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
fig.colorbar(SM, ax=axes, label="PMMA thickness / nm")
plt.show(block=False)

# %%
## Order 2 demodulation for the original snompy example

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# Set some experimental parameters
A_tip = 20e-9  # AFM tip tapping amplitude
r_tip = 30e-9  # AFM tip radius of curvature
L_tip = 350e-9  # Semi-major axis length of ellipsoid tip model
n = 2  # Harmonic for demodulation
theta_in = np.deg2rad(60)  # Light angle of incidence
c_r = 0.3  # Experimental weighting factor
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # Vacuum wavenumber
method = "Q_ave"  # The FDM method to use

# Semi-infinite superstrate and substrate
eps_air = 1.0
eps_Si = 11.7  # Si permitivitty in the mid-infrared

# Very simplified model of PMMA dielectric function based on ref [1] below
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = np.geomspace(1, 35, 32) * 1e-9  # A range of thicknesses
sample_pmma = snompy.Sample(
    eps_stack=(eps_air, eps_pmma, eps_Si),
    t_stack=(t_pmma[:, np.newaxis],),
    nu_vac=nu_vac,
)

# Model of Au dielectric function from ref [2] below
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# Measurement
alpha_eff_pmma = snompy.fdm.eff_pol_n(
    sample=sample_pmma, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_pmma = sample_pmma.refl_coef(theta_in=theta_in)
sigma_pmma = (1 + c_r * r_coef_pmma) ** 2 * alpha_eff_pmma

# Gold reference
alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalised complex scattering
eta_n = sigma_pmma / sigma_Au

# Plot output
fig, axes = plt.subplots(nrows=2, sharex=True)

# For neater plotting
nu_per_cm = nu_vac * 1e-2
t_nm = t_pmma * 1e9

SM = plt.cm.ScalarMappable(
    cmap=plt.cm.Spectral_r, norm=Normalize(vmin=t_nm.min(), vmax=t_nm.max())
)  # This maps thickness to colour

for t, sigma in zip(t_nm, eta_n):
    c = SM.to_rgba(t)
    axes[0].plot(nu_per_cm, np.abs(sigma), c=c)
    axes[1].plot(nu_per_cm, np.angle(sigma), c=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
cbar = fig.colorbar(SM, ax=axes, label="PMMA thickness / nm")
plt.show(block=False)

# %%
## Order 4 demodulation for the original snompy example

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# Set some experimental parameters
A_tip = 20e-9  # AFM tip tapping amplitude
r_tip = 30e-9  # AFM tip radius of curvature
L_tip = 350e-9  # Semi-major axis length of ellipsoid tip model
n = 4  # Harmonic for demodulation
theta_in = np.deg2rad(60)  # Light angle of incidence
c_r = 0.3  # Experimental weighting factor
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # Vacuum wavenumber
method = "Q_ave"  # The FDM method to use

# Semi-infinite superstrate and substrate
eps_air = 1.0
eps_Si = 11.7  # Si permitivitty in the mid-infrared

# Very simplified model of PMMA dielectric function based on ref [1] below
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = np.geomspace(1, 35, 32) * 1e-9  # A range of thicknesses
sample_pmma = snompy.Sample(
    eps_stack=(eps_air, eps_pmma, eps_Si),
    t_stack=(t_pmma[:, np.newaxis],),
    nu_vac=nu_vac,
)

# Model of Au dielectric function from ref [2] below
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# Measurement
alpha_eff_pmma = snompy.fdm.eff_pol_n(
    sample=sample_pmma, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_pmma = sample_pmma.refl_coef(theta_in=theta_in)
sigma_pmma = (1 + c_r * r_coef_pmma) ** 2 * alpha_eff_pmma

# Gold reference
alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalised complex scattering
eta_n = sigma_pmma / sigma_Au

# Plot output
fig, axes = plt.subplots(nrows=2, sharex=True)

# For neater plotting
nu_per_cm = nu_vac * 1e-2
t_nm = t_pmma * 1e9

SM = plt.cm.ScalarMappable(
    cmap=plt.cm.Spectral_r, norm=Normalize(vmin=t_nm.min(), vmax=t_nm.max())
)  # This maps thickness to colour

for t, sigma in zip(t_nm, eta_n):
    c = SM.to_rgba(t)
    axes[0].plot(nu_per_cm, np.abs(sigma), c=c)
    axes[1].plot(nu_per_cm, np.angle(sigma), c=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
cbar = fig.colorbar(SM, ax=axes, label="PMMA thickness / nm")
plt.show(block=False)

# %%
## Order 2 demodulation for the original simulation

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# Set some experimental parameters
A_tip = 20e-9  # AFM tip tapping amplitude
r_tip = 30e-9  # AFM tip radius of curvature
L_tip = 350e-9  # Semi-major axis length of ellipsoid tip model
n = 2  # Harmonic for demodulation
theta_in = np.deg2rad(60)  # Light angle of incidence
c_r = 0.3  # Experimental weighting factor
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # Vacuum wavenumber
method = "Q_ave"  # The FDM method to use

# Semi-infinite superstrate and substrate
eps_air = 1.0
eps_Si = 11.7  # Si permitivitty in the mid-infrared

# Very simplified model of PMMA dielectric function based on ref [1] below
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = np.geomspace(1, 35, 32) * 1e-9  # A range of thicknesses
sample_pmma = snompy.Sample(
    eps_stack=(eps_air, eps_pmma, eps_Si),
    t_stack=(t_pmma[:, np.newaxis],),
    nu_vac=nu_vac,
)

# Model of Au dielectric function from ref [2] below
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# Measurement
alpha_eff_pmma = snompy.fdm.eff_pol_n(
    sample=sample_pmma, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_pmma = sample_pmma.refl_coef(theta_in=theta_in)
sigma_pmma = (1 + c_r * r_coef_pmma) ** 2 * alpha_eff_pmma

# Gold reference
alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalised complex scattering
eta_n = sigma_pmma / sigma_Au

# Plot output
fig, axes = plt.subplots(nrows=2, sharex=True)

# For neater plotting
nu_per_cm = nu_vac * 1e-2
t_nm = t_pmma * 1e9

SM = plt.cm.ScalarMappable(
    cmap=plt.cm.Spectral_r, norm=Normalize(vmin=t_nm.min(), vmax=t_nm.max())
)  # This maps thickness to colour

for t, sigma in zip(t_nm, eta_n):
    c = SM.to_rgba(t)
    axes[0].plot(nu_per_cm, np.abs(sigma), c=c)
    axes[1].plot(nu_per_cm, np.angle(sigma), c=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
cbar = fig.colorbar(SM, ax=axes, label="PMMA thickness / nm")
plt.show(block=False)

# %%
## Fixed thickness of PMMA 30 nm (Order 2 demodulation for the original simulation)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize
import snompy

# ----------------------------
# Experimental parameters
# ----------------------------
A_tip = 20e-9       # AFM tip tapping amplitude
r_tip = 30e-9       # AFM tip radius of curvature
L_tip = 350e-9      # Semi-major axis length of ellipsoid tip model
n = 2               # 2nd harmonic for demodulation
theta_in = np.deg2rad(60)  # Light angle of incidence
c_r = 0.3           # Experimental weighting factor
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # Vacuum wavenumber
method = "Q_ave"    # FDM method

# ----------------------------
# Dielectric constants
# ----------------------------
eps_air = 1.0
eps_Si = 11.7  # Si permitivitty in the mid-infrared

# PMMA (fixed 30 nm)
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = 30e-9  # fixed thickness
sample_pmma = snompy.Sample(
    eps_stack=(eps_air, eps_pmma, eps_Si),
    t_stack=(np.array([t_pmma])[:, np.newaxis],),
    nu_vac=nu_vac
)

# Gold reference
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# ----------------------------
# Measurement
# ----------------------------
alpha_eff_pmma = snompy.fdm.eff_pol_n(
    sample=sample_pmma, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_pmma = sample_pmma.refl_coef(theta_in=theta_in)
sigma_pmma = (1 + c_r * r_coef_pmma) ** 2 * alpha_eff_pmma

# Gold reference
alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalized complex scattering
eta_n = sigma_pmma / sigma_Au

# ----------------------------
# Plot
# ----------------------------
fig, axes = plt.subplots(nrows=2, sharex=True, figsize=(7,5))
nu_per_cm = nu_vac * 1e-2

axes[0].plot(nu_per_cm, np.abs(eta_n[0]), label=f"PMMA {t_pmma*1e9:.0f} nm")
axes[1].plot(nu_per_cm, np.angle(eta_n[0]), label=f"PMMA {t_pmma*1e9:.0f} nm")

axes[0].set_ylabel(r"$|s_{" f"{n}" r"}|$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)

axes[0].legend()
fig.tight_layout()
plt.show()

# %%
## Fixed thickness of PMMA 30 nm (Order 3 demodulation for the original simulation)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize
import snompy

# ----------------------------
# Experimental parameters
# ----------------------------
A_tip = 20e-9       # AFM tip tapping amplitude
r_tip = 30e-9       # AFM tip radius of curvature
L_tip = 350e-9      # Semi-major axis length of ellipsoid tip model
n = 3               # 2nd harmonic for demodulation
theta_in = np.deg2rad(60)  # Light angle of incidence
c_r = 0.3           # Experimental weighting factor
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # Vacuum wavenumber
method = "Q_ave"    # FDM method

# ----------------------------
# Dielectric constants
# ----------------------------
eps_air = 1.0
eps_Si = 11.7  # Si permitivitty in the mid-infrared

# PMMA (fixed 30 nm)
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = 30e-9  # fixed thickness
sample_pmma = snompy.Sample(
    eps_stack=(eps_air, eps_pmma, eps_Si),
    t_stack=(np.array([t_pmma])[:, np.newaxis],),
    nu_vac=nu_vac
)

# Gold reference
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# ----------------------------
# Measurement
# ----------------------------
alpha_eff_pmma = snompy.fdm.eff_pol_n(
    sample=sample_pmma, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_pmma = sample_pmma.refl_coef(theta_in=theta_in)
sigma_pmma = (1 + c_r * r_coef_pmma) ** 2 * alpha_eff_pmma

# Gold reference
alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalized complex scattering
eta_n = sigma_pmma / sigma_Au

# ----------------------------
# Plot
# ----------------------------
fig, axes = plt.subplots(nrows=2, sharex=True, figsize=(7,5))
nu_per_cm = nu_vac * 1e-2

axes[0].plot(nu_per_cm, np.abs(eta_n[0]), label=f"PMMA {t_pmma*1e9:.0f} nm")
axes[1].plot(nu_per_cm, np.angle(eta_n[0]), label=f"PMMA {t_pmma*1e9:.0f} nm")

axes[0].set_ylabel(r"$|s_{" f"{n}" r"}|$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)

axes[0].legend()
fig.tight_layout()
plt.show()

# %%
## Fixed thickness of PMMA 30 nm (Order 4 demodulation for the original simulation)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize
import snompy

# ----------------------------
# Experimental parameters
# ----------------------------
A_tip = 20e-9       # AFM tip tapping amplitude
r_tip = 30e-9       # AFM tip radius of curvature
L_tip = 350e-9      # Semi-major axis length of ellipsoid tip model
n = 4               # 2nd harmonic for demodulation
theta_in = np.deg2rad(60)  # Light angle of incidence
c_r = 0.3           # Experimental weighting factor
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # Vacuum wavenumber
method = "Q_ave"    # FDM method

# ----------------------------
# Dielectric constants
# ----------------------------
eps_air = 1.0
eps_Si = 11.7  # Si permitivitty in the mid-infrared

# PMMA (fixed 30 nm)
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = 30e-9  # fixed thickness
sample_pmma = snompy.Sample(
    eps_stack=(eps_air, eps_pmma, eps_Si),
    t_stack=(np.array([t_pmma])[:, np.newaxis],),
    nu_vac=nu_vac
)

# Gold reference
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# ----------------------------
# Measurement
# ----------------------------
alpha_eff_pmma = snompy.fdm.eff_pol_n(
    sample=sample_pmma, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_pmma = sample_pmma.refl_coef(theta_in=theta_in)
sigma_pmma = (1 + c_r * r_coef_pmma) ** 2 * alpha_eff_pmma

# Gold reference
alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalized complex scattering
eta_n = sigma_pmma / sigma_Au

# ----------------------------
# Plot
# ----------------------------
fig, axes = plt.subplots(nrows=2, sharex=True, figsize=(7,5))
nu_per_cm = nu_vac * 1e-2

axes[0].plot(nu_per_cm, np.abs(eta_n[0]), label=f"PMMA {t_pmma*1e9:.0f} nm")
axes[1].plot(nu_per_cm, np.angle(eta_n[0]), label=f"PMMA {t_pmma*1e9:.0f} nm")

axes[0].set_ylabel(r"$|s_{" f"{n}" r"}|$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)

axes[0].legend()
fig.tight_layout()
plt.show()

# %%
## Combines graphs n=2,3,4

# %%
import matplotlib.pyplot as plt
import numpy as np
import snompy
import os

# ----------------------------
# Folder to save figure
# ----------------------------
save_folder = r"C:\Users\user\OneDrive\Desktop\Snompy"  # Windows path as raw string
os.makedirs(save_folder, exist_ok=True)  # create folder if it doesn't exist
save_path = os.path.join(save_folder, "PMMA_demodulation_orders.png")

# ----------------------------
# Experimental parameters
# ----------------------------
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2
method = "Q_ave"

# ----------------------------
# Dielectric constants
# ----------------------------
eps_air = 1.0
eps_Si = 11.7

eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = 30e-9
sample_pmma = snompy.Sample(
    eps_stack=(eps_air, eps_pmma, eps_Si),
    t_stack=(np.array([t_pmma])[:, np.newaxis],),
    nu_vac=nu_vac
)

eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# ----------------------------
# Demodulation orders
# ----------------------------
demod_orders = [2, 3, 4]
eta_list = []

for n in demod_orders:
    alpha_eff = snompy.fdm.eff_pol_n(
        sample=sample_pmma, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
    )
    r_coef = sample_pmma.refl_coef(theta_in=theta_in)
    sigma = (1 + c_r * r_coef) ** 2 * alpha_eff

    alpha_eff_Au = snompy.fdm.eff_pol_n(
        sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
    )
    r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
    sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

    eta_list.append(sigma / sigma_Au)

# ----------------------------
# Plot
# ----------------------------
nu_per_cm = nu_vac * 1e-2
fig, axes = plt.subplots(nrows=2, sharex=True, figsize=(8,5))

colors = ['tab:blue', 'tab:orange', 'tab:green']

for eta, n, c in zip(eta_list, demod_orders, colors):
    axes[0].plot(nu_per_cm, np.abs(eta[0]), label=f"n={n}", color=c)
    axes[1].plot(nu_per_cm, np.angle(eta[0]), label=f"n={n}", color=c)

axes[0].set_ylabel(r"$|s_n|$ / a.u.")
axes[1].set_ylabel(r"$\phi_n$ / rad")
axes[1].set_xlabel(r"$\nu$ / cm$^{-1}$")
axes[1].set_xlim(nu_per_cm.max(), nu_per_cm.min())
axes[0].legend()
fig.tight_layout()

# ----------------------------
# Save to specific folder
# ----------------------------
plt.savefig(save_path, dpi=300, bbox_inches='tight')
plt.show()

print(f"Figure saved at: {save_path}")
# Out:
# Figure saved at: C:\Users\user\OneDrive\Desktop\Snompy\PMMA_demodulation_orders.png

# %%
## Order 2 demodulation for Si3N4

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# Experimental parameters
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
n = 2
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2
method = "Q_ave"

# Semi-infinite superstrate and substrate
eps_air = 1.0
eps_Si = 11.7  # mid-IR permittivity of Si

# Si3N4 dielectric function (Lorentz-like model for mid-IR absorption)
eps_Si3N4 = snompy.sample.lorentz_perm(
    nu_vac,
    nu_j=900e2,      # main absorption peak ~11 µm
    gamma_j=50e2,    # damping
    A_j=2e8,         # strength
    eps_inf=4.0      # high-frequency permittivity
)

t_Si3N4 = 15e-9  # fixed thickness of Si3N4

# PMMA dielectric function (simplified model)
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = np.geomspace(1, 35, 32) * 1e-9

# Define the 4-layer stack: air / Si3N4 / PMMA / Si
sample_stack = snompy.Sample(
    eps_stack=(eps_air, eps_Si3N4, eps_pmma, eps_Si),
    t_stack=(np.full_like(t_pmma, t_Si3N4)[:, np.newaxis],
             t_pmma[:, np.newaxis]),
    nu_vac=nu_vac,
)

# Gold reference
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# Measurement
alpha_eff_stack = snompy.fdm.eff_pol_n(
    sample=sample_stack, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_stack = sample_stack.refl_coef(theta_in=theta_in)
sigma_stack = (1 + c_r * r_coef_stack) ** 2 * alpha_eff_stack

alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalised complex scattering
eta_n = sigma_stack / sigma_Au

# Plot output
fig, axes = plt.subplots(nrows=2, sharex=True)

nu_per_cm = nu_vac * 1e-2
t_nm = t_pmma * 1e9

SM = plt.cm.ScalarMappable(
    cmap=plt.cm.Spectral_r, norm=Normalize(vmin=t_nm.min(), vmax=t_nm.max())
)

for t, sigma in zip(t_nm, eta_n):
    c = SM.to_rgba(t)
    axes[0].plot(nu_per_cm, np.abs(sigma), c=c)
    axes[1].plot(nu_per_cm, np.angle(sigma), c=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
fig.colorbar(SM, ax=axes, label="PMMA thickness / nm")
plt.show(block=False)

# %%
## Order 4 demodulation for Si3N4

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# Experimental parameters
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
n = 4
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2
method = "Q_ave"

# Semi-infinite superstrate and substrate
eps_air = 1.0
eps_Si = 11.7  # mid-IR permittivity of Si

# Si3N4 dielectric function (Lorentz-like model for mid-IR absorption)
eps_Si3N4 = snompy.sample.lorentz_perm(
    nu_vac,
    nu_j=900e2,      # main absorption peak ~11 µm
    gamma_j=50e2,    # damping
    A_j=2e8,         # strength
    eps_inf=4.0      # high-frequency permittivity
)

t_Si3N4 = 15e-9  # fixed thickness of Si3N4

# PMMA dielectric function (simplified model)
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = np.geomspace(1, 35, 32) * 1e-9

# Define the 4-layer stack: air / Si3N4 / PMMA / Si
sample_stack = snompy.Sample(
    eps_stack=(eps_air, eps_Si3N4, eps_pmma, eps_Si),
    t_stack=(np.full_like(t_pmma, t_Si3N4)[:, np.newaxis],
             t_pmma[:, np.newaxis]),
    nu_vac=nu_vac,
)

# Gold reference
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# Measurement
alpha_eff_stack = snompy.fdm.eff_pol_n(
    sample=sample_stack, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_stack = sample_stack.refl_coef(theta_in=theta_in)
sigma_stack = (1 + c_r * r_coef_stack) ** 2 * alpha_eff_stack

alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalised complex scattering
eta_n = sigma_stack / sigma_Au

# Plot output
fig, axes = plt.subplots(nrows=2, sharex=True)

nu_per_cm = nu_vac * 1e-2
t_nm = t_pmma * 1e9

SM = plt.cm.ScalarMappable(
    cmap=plt.cm.Spectral_r, norm=Normalize(vmin=t_nm.min(), vmax=t_nm.max())
)

for t, sigma in zip(t_nm, eta_n):
    c = SM.to_rgba(t)
    axes[0].plot(nu_per_cm, np.abs(sigma), c=c)
    axes[1].plot(nu_per_cm, np.angle(sigma), c=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
fig.colorbar(SM, ax=axes, label="PMMA thickness / nm")
plt.show(block=False)

# %%
## Fixed thickness of PMMA 30 nm (Order 4 demodulation for Si3N4)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize
import snompy

# Experimental parameters
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
n = 4
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2
method = "Q_ave"

# Semi-infinite superstrate and substrate
eps_air = 1.0
eps_Si = 11.7  # mid-IR permittivity of Si

# Si3N4 dielectric function
eps_Si3N4 = snompy.sample.lorentz_perm(
    nu_vac,
    nu_j=900e2,
    gamma_j=50e2,
    A_j=2e8,
    eps_inf=4.0
)

t_Si3N4 = 15e-9  # fixed thickness of Si3N4

# PMMA dielectric function
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = 30e-9  # fixed PMMA thickness

# Define the 4-layer stack: air / Si3N4 / PMMA / Si
sample_stack = snompy.Sample(
    eps_stack=(eps_air, eps_Si3N4, eps_pmma, eps_Si),
    t_stack=(t_Si3N4, t_pmma),
    nu_vac=nu_vac,
)

# Gold reference
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# Measurement for stack
alpha_eff_stack = snompy.fdm.eff_pol_n(
    sample=sample_stack, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_stack = sample_stack.refl_coef(theta_in=theta_in)
sigma_stack = (1 + c_r * r_coef_stack) ** 2 * alpha_eff_stack

# Measurement for gold
alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalised complex scattering
eta_n = sigma_stack / sigma_Au

# Plot output
fig, axes = plt.subplots(nrows=2, sharex=True)

nu_per_cm = nu_vac * 1e-2
c = 'tab:blue'  # single color

axes[0].plot(nu_per_cm, np.abs(eta_n), color=c)
axes[1].plot(nu_per_cm, np.angle(eta_n), color=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
plt.show(block=False)

# %%
## Fixed thickness of PMMA 30 nm (Order 3 demodulation for Si3N4)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize
import snompy

# Experimental parameters
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
n = 3
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2
method = "Q_ave"

# Semi-infinite superstrate and substrate
eps_air = 1.0
eps_Si = 11.7  # mid-IR permittivity of Si

# Si3N4 dielectric function
eps_Si3N4 = snompy.sample.lorentz_perm(
    nu_vac,
    nu_j=900e2,
    gamma_j=50e2,
    A_j=2e8,
    eps_inf=4.0
)

t_Si3N4 = 15e-9  # fixed thickness of Si3N4

# PMMA dielectric function
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = 30e-9  # fixed PMMA thickness

# Define the 4-layer stack: air / Si3N4 / PMMA / Si
sample_stack = snompy.Sample(
    eps_stack=(eps_air, eps_Si3N4, eps_pmma, eps_Si),
    t_stack=(t_Si3N4, t_pmma),
    nu_vac=nu_vac,
)

# Gold reference
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# Measurement for stack
alpha_eff_stack = snompy.fdm.eff_pol_n(
    sample=sample_stack, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_stack = sample_stack.refl_coef(theta_in=theta_in)
sigma_stack = (1 + c_r * r_coef_stack) ** 2 * alpha_eff_stack

# Measurement for gold
alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalised complex scattering
eta_n = sigma_stack / sigma_Au

# Plot output
fig, axes = plt.subplots(nrows=2, sharex=True)

nu_per_cm = nu_vac * 1e-2
c = 'tab:blue'  # single color

axes[0].plot(nu_per_cm, np.abs(eta_n), color=c)
axes[1].plot(nu_per_cm, np.angle(eta_n), color=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
plt.show(block=False)

# %%
## Fixed thickness of PMMA 30 nm (Order 2 demodulation for Si3N4)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize
import snompy

# Experimental parameters
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
n = 2
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2
method = "Q_ave"

# Semi-infinite superstrate and substrate
eps_air = 1.0
eps_Si = 11.7  # mid-IR permittivity of Si

# Si3N4 dielectric function
eps_Si3N4 = snompy.sample.lorentz_perm(
    nu_vac,
    nu_j=900e2,
    gamma_j=50e2,
    A_j=2e8,
    eps_inf=4.0
)

t_Si3N4 = 15e-9  # fixed thickness of Si3N4

# PMMA dielectric function
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = 30e-9  # fixed PMMA thickness

# Define the 4-layer stack: air / Si3N4 / PMMA / Si
sample_stack = snompy.Sample(
    eps_stack=(eps_air, eps_Si3N4, eps_pmma, eps_Si),
    t_stack=(t_Si3N4, t_pmma),
    nu_vac=nu_vac,
)

# Gold reference
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# Measurement for stack
alpha_eff_stack = snompy.fdm.eff_pol_n(
    sample=sample_stack, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_stack = sample_stack.refl_coef(theta_in=theta_in)
sigma_stack = (1 + c_r * r_coef_stack) ** 2 * alpha_eff_stack

# Measurement for gold
alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# Normalised complex scattering
eta_n = sigma_stack / sigma_Au

# Plot output
fig, axes = plt.subplots(nrows=2, sharex=True)

nu_per_cm = nu_vac * 1e-2
c = 'tab:blue'  # single color

axes[0].plot(nu_per_cm, np.abs(eta_n), color=c)
axes[1].plot(nu_per_cm, np.angle(eta_n), color=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
plt.show(block=False)

# %%
## Combined code for n=2,3,4 for Si3n4

# %%
import matplotlib.pyplot as plt
import numpy as np
import snompy

# ----------------------------
# Common Experimental Parameters
# ----------------------------
A_tip = 20e-9       # AFM tip tapping amplitude
r_tip = 30e-9       # Tip radius
L_tip = 350e-9      # Ellipsoid tip semi-major axis
theta_in = np.deg2rad(60)  # Incidence angle
c_r = 0.3           # Coupling factor
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # Wavenumber in m^-1
method = "Q_ave"    # FDM method

# ----------------------------
# Dielectric constants
# ----------------------------
eps_air = 1.0
eps_Si = 11.7  # Mid-IR Si
eps_Si3N4 = snompy.sample.lorentz_perm(
    nu_vac, nu_j=900e2, gamma_j=50e2, A_j=2e8, eps_inf=4.0
)
t_Si3N4 = 15e-9

eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = 30e-9  # fixed thickness

# Gold reference
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# ----------------------------
# Demodulation orders to compare
# ----------------------------
demod_orders = [2, 3, 4]
eta_list = []

for n in demod_orders:
    # Build sample stack: air / Si3N4 / PMMA / Si
    sample_stack = snompy.Sample(
        eps_stack=(eps_air, eps_Si3N4, eps_pmma, eps_Si),
        t_stack=(t_Si3N4, t_pmma),
        nu_vac=nu_vac,
    )

    # Measurement for stack
    alpha_eff_stack = snompy.fdm.eff_pol_n(
        sample=sample_stack, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
    )
    r_coef_stack = sample_stack.refl_coef(theta_in=theta_in)
    sigma_stack = (1 + c_r * r_coef_stack) ** 2 * alpha_eff_stack

    # Measurement for gold
    alpha_eff_Au = snompy.fdm.eff_pol_n(
        sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
    )
    r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
    sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

    # Normalized complex scattering
    eta_n = sigma_stack / sigma_Au
    eta_list.append(eta_n)

# ----------------------------
# Plotting
# ----------------------------
fig, axes = plt.subplots(nrows=2, sharex=True, figsize=(8,5))
nu_per_cm = nu_vac * 1e-2

colors = ['tab:blue', 'tab:orange', 'tab:green']

for eta, n, c in zip(eta_list, demod_orders, colors):
    axes[0].plot(nu_per_cm, np.abs(eta), label=f"n={n}", color=c)
    axes[1].plot(nu_per_cm, np.angle(eta), label=f"n={n}", color=c)

axes[0].set_ylabel(r"$|s_n|$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_n$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)

# Move legend to the right outside the plot
axes[0].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))

fig.tight_layout()
fig.subplots_adjust(right=0.75)  # make room on the right for legend

# Save figure
save_path = r"C:\Users\user\OneDrive\Desktop\Snompy\demod_comparison.png"
fig.savefig(save_path, dpi=300)
print(f"Figure saved at: {save_path}")

plt.show()
# Out:
# Figure saved at: C:\Users\user\OneDrive\Desktop\Snompy\demod_comparison.png

# %%
## Order 2 demodulation for Graphene

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# -----------------------
# Experimental parameters
# -----------------------
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
n = 2
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # [m^-1] as in your original code (cm^-1 * 1e2)
method = "Q_ave"

# -------------------------------
# Media: air (superstrate) & Si (substrate)
# -------------------------------
eps_air = 1.0
eps_Si = 11.7  # approximate mid-IR permittivity of Si

# -------------------------------------------------------
# PMMA dielectric function (same synthetic Lorentz model)
# -------------------------------------------------------
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2.0
)
t_pmma = np.geomspace(1, 35, 32) * 1e-9  # 1–35 nm

# -------------------------------------------------------
# Graphene monolayer (0.3 nm) via sheet conductivity σ0
# -------------------------------------------------------
# Constants
eps0 = 8.8541878128e-12  # F/m
c0   = 299792458.0       # m/s
e    = 1.602176634e-19   # C
hbar = 1.054571817e-34   # J*s

sigma0 = e**2 / (4*hbar)   # ~6.085e-5 S (universal interband sheet conductivity)
t_g = 0.3e-9               # 0.3 nm monolayer thickness

# Angular frequency omega = 2π * c * k0, with k0 = nu_vac [m^-1]
omega = 2*np.pi * c0 * (nu_vac * 1.0)  # [rad/s]

# Effective bulk permittivity for ultra-thin film:
# eps_g(ω) = 1 + i * sigma_sheet / (eps0 * ω * t_g)
eps_graphene = 1.0 + 1j * sigma0 / (eps0 * omega * t_g)

# -------------------------------------------------------
# Build 4-layer sample: air / graphene / PMMA / Si
# -------------------------------------------------------
sample_stack = snompy.Sample(
    eps_stack=(eps_air, eps_graphene, eps_pmma, eps_Si),
    t_stack=(np.full_like(t_pmma, t_g)[:, np.newaxis],   # fixed graphene thickness
             t_pmma[:, np.newaxis]),                     # varying PMMA thickness
    nu_vac=nu_vac,
)

# --------------------
# Gold reference (Au)
# --------------------
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# --------------------
# Measurement signals
# --------------------
alpha_eff_stack = snompy.fdm.eff_pol_n(
    sample=sample_stack, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_stack = sample_stack.refl_coef(theta_in=theta_in)
sigma_stack = (1 + c_r * r_coef_stack) ** 2 * alpha_eff_stack

alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# -------------------------------
# Normalized complex scattering
# -------------------------------
eta_n = sigma_stack / sigma_Au

# -----------
# Plotting
# -----------
fig, axes = plt.subplots(nrows=2, sharex=True)

nu_per_cm = nu_vac * 1e-2        # for axis labeling (cm^-1)
t_nm = t_pmma * 1e9              # PMMA thickness in nm

SM = plt.cm.ScalarMappable(
    cmap=plt.cm.Spectral_r, norm=Normalize(vmin=t_nm.min(), vmax=t_nm.max())
)

for t, sigma in zip(t_nm, eta_n):
    c = SM.to_rgba(t)
    axes[0].plot(nu_per_cm, np.abs(sigma), c=c)
    axes[1].plot(nu_per_cm, np.angle(sigma), c=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
fig.colorbar(SM, ax=axes, label="PMMA thickness / nm")
plt.show(block=False)

# %%
## Order 4 demodulation for Graphene

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# -----------------------
# Experimental parameters
# -----------------------
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
n = 4
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # [m^-1] as in your original code (cm^-1 * 1e2)
method = "Q_ave"

# -------------------------------
# Media: air (superstrate) & Si (substrate)
# -------------------------------
eps_air = 1.0
eps_Si = 11.7  # approximate mid-IR permittivity of Si

# -------------------------------------------------------
# PMMA dielectric function (same synthetic Lorentz model)
# -------------------------------------------------------
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2.0
)
t_pmma = np.geomspace(1, 35, 32) * 1e-9  # 1–35 nm

# -------------------------------------------------------
# Graphene monolayer (0.3 nm) via sheet conductivity σ0
# -------------------------------------------------------
# Constants
eps0 = 8.8541878128e-12  # F/m
c0   = 299792458.0       # m/s
e    = 1.602176634e-19   # C
hbar = 1.054571817e-34   # J*s

sigma0 = e**2 / (4*hbar)   # ~6.085e-5 S (universal interband sheet conductivity)
t_g = 0.3e-9               # 0.3 nm monolayer thickness

# Angular frequency omega = 2π * c * k0, with k0 = nu_vac [m^-1]
omega = 2*np.pi * c0 * (nu_vac * 1.0)  # [rad/s]

# Effective bulk permittivity for ultra-thin film:
# eps_g(ω) = 1 + i * sigma_sheet / (eps0 * ω * t_g)
eps_graphene = 1.0 + 1j * sigma0 / (eps0 * omega * t_g)

# -------------------------------------------------------
# Build 4-layer sample: air / graphene / PMMA / Si
# -------------------------------------------------------
sample_stack = snompy.Sample(
    eps_stack=(eps_air, eps_graphene, eps_pmma, eps_Si),
    t_stack=(np.full_like(t_pmma, t_g)[:, np.newaxis],   # fixed graphene thickness
             t_pmma[:, np.newaxis]),                     # varying PMMA thickness
    nu_vac=nu_vac,
)

# --------------------
# Gold reference (Au)
# --------------------
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# --------------------
# Measurement signals
# --------------------
alpha_eff_stack = snompy.fdm.eff_pol_n(
    sample=sample_stack, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_stack = sample_stack.refl_coef(theta_in=theta_in)
sigma_stack = (1 + c_r * r_coef_stack) ** 2 * alpha_eff_stack

alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# -------------------------------
# Normalized complex scattering
# -------------------------------
eta_n = sigma_stack / sigma_Au

# -----------
# Plotting
# -----------
fig, axes = plt.subplots(nrows=2, sharex=True)

nu_per_cm = nu_vac * 1e-2        # for axis labeling (cm^-1)
t_nm = t_pmma * 1e9              # PMMA thickness in nm

SM = plt.cm.ScalarMappable(
    cmap=plt.cm.Spectral_r, norm=Normalize(vmin=t_nm.min(), vmax=t_nm.max())
)

for t, sigma in zip(t_nm, eta_n):
    c = SM.to_rgba(t)
    axes[0].plot(nu_per_cm, np.abs(sigma), c=c)
    axes[1].plot(nu_per_cm, np.angle(sigma), c=c)

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
fig.colorbar(SM, ax=axes, label="PMMA thickness / nm")
plt.show(block=False)

# %%
## Fixed thickness of PMMA 30 nm (## Order 4 demodulation for Graphene)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# -----------------------
# Experimental parameters
# -----------------------
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
n = 4
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # [m^-1]
method = "Q_ave"

# -------------------------------
# Media: air (superstrate) & Si (substrate)
# -------------------------------
eps_air = 1.0
eps_Si = 11.7

# -------------------------------------------------------
# PMMA dielectric function (synthetic Lorentz model)
# -------------------------------------------------------
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2.0
)
t_pmma = np.array([30e-9])  # fixed at 30 nm

# -------------------------------------------------------
# Graphene monolayer (0.3 nm) via sheet conductivity σ0
# -------------------------------------------------------
eps0 = 8.8541878128e-12
c0   = 299792458.0
e    = 1.602176634e-19
hbar = 1.054571817e-34

sigma0 = e**2 / (4*hbar)
t_g = 0.3e-9

omega = 2*np.pi * c0 * nu_vac
eps_graphene = 1.0 + 1j * sigma0 / (eps0 * omega * t_g)

# -------------------------------------------------------
# Build sample: air / graphene / PMMA / Si
# -------------------------------------------------------
sample_stack = snompy.Sample(
    eps_stack=(eps_air, eps_graphene, eps_pmma, eps_Si),
    t_stack=(np.full_like(t_pmma, t_g)[:, np.newaxis],
             t_pmma[:, np.newaxis]),
    nu_vac=nu_vac,
)

# --------------------
# Gold reference (Au)
# --------------------
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# --------------------
# Measurement signals
# --------------------
alpha_eff_stack = snompy.fdm.eff_pol_n(
    sample=sample_stack, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_stack = sample_stack.refl_coef(theta_in=theta_in)
sigma_stack = (1 + c_r * r_coef_stack) ** 2 * alpha_eff_stack

alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# -------------------------------
# Normalized complex scattering
# -------------------------------
eta_n = sigma_stack / sigma_Au

# -----------
# Plotting
# -----------
nu_per_cm = nu_vac * 1e-2

fig, axes = plt.subplots(nrows=2, sharex=True)
axes[0].plot(nu_per_cm, np.abs(eta_n[0]))
axes[1].plot(nu_per_cm, np.angle(eta_n[0]))

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
plt.show()

# %%
## Fixed thickness of PMMA 30 nm (## Order 3 demodulation for Graphene)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# -----------------------
# Experimental parameters
# -----------------------
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
n = 3
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # [m^-1]
method = "Q_ave"

# -------------------------------
# Media: air (superstrate) & Si (substrate)
# -------------------------------
eps_air = 1.0
eps_Si = 11.7

# -------------------------------------------------------
# PMMA dielectric function (synthetic Lorentz model)
# -------------------------------------------------------
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2.0
)
t_pmma = np.array([30e-9])  # fixed at 30 nm

# -------------------------------------------------------
# Graphene monolayer (0.3 nm) via sheet conductivity σ0
# -------------------------------------------------------
eps0 = 8.8541878128e-12
c0   = 299792458.0
e    = 1.602176634e-19
hbar = 1.054571817e-34

sigma0 = e**2 / (4*hbar)
t_g = 0.3e-9

omega = 2*np.pi * c0 * nu_vac
eps_graphene = 1.0 + 1j * sigma0 / (eps0 * omega * t_g)

# -------------------------------------------------------
# Build sample: air / graphene / PMMA / Si
# -------------------------------------------------------
sample_stack = snompy.Sample(
    eps_stack=(eps_air, eps_graphene, eps_pmma, eps_Si),
    t_stack=(np.full_like(t_pmma, t_g)[:, np.newaxis],
             t_pmma[:, np.newaxis]),
    nu_vac=nu_vac,
)

# --------------------
# Gold reference (Au)
# --------------------
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# --------------------
# Measurement signals
# --------------------
alpha_eff_stack = snompy.fdm.eff_pol_n(
    sample=sample_stack, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_stack = sample_stack.refl_coef(theta_in=theta_in)
sigma_stack = (1 + c_r * r_coef_stack) ** 2 * alpha_eff_stack

alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# -------------------------------
# Normalized complex scattering
# -------------------------------
eta_n = sigma_stack / sigma_Au

# -----------
# Plotting
# -----------
nu_per_cm = nu_vac * 1e-2

fig, axes = plt.subplots(nrows=2, sharex=True)
axes[0].plot(nu_per_cm, np.abs(eta_n[0]))
axes[1].plot(nu_per_cm, np.angle(eta_n[0]))

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
plt.show()

# %%
## Fixed thickness of PMMA 30 nm (## Order 2 demodulation for Graphene)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize

import snompy

# -----------------------
# Experimental parameters
# -----------------------
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
n = 2
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # [m^-1]
method = "Q_ave"

# -------------------------------
# Media: air (superstrate) & Si (substrate)
# -------------------------------
eps_air = 1.0
eps_Si = 11.7

# -------------------------------------------------------
# PMMA dielectric function (synthetic Lorentz model)
# -------------------------------------------------------
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2.0
)
t_pmma = np.array([30e-9])  # fixed at 30 nm

# -------------------------------------------------------
# Graphene monolayer (0.3 nm) via sheet conductivity σ0
# -------------------------------------------------------
eps0 = 8.8541878128e-12
c0   = 299792458.0
e    = 1.602176634e-19
hbar = 1.054571817e-34

sigma0 = e**2 / (4*hbar)
t_g = 0.3e-9

omega = 2*np.pi * c0 * nu_vac
eps_graphene = 1.0 + 1j * sigma0 / (eps0 * omega * t_g)

# -------------------------------------------------------
# Build sample: air / graphene / PMMA / Si
# -------------------------------------------------------
sample_stack = snompy.Sample(
    eps_stack=(eps_air, eps_graphene, eps_pmma, eps_Si),
    t_stack=(np.full_like(t_pmma, t_g)[:, np.newaxis],
             t_pmma[:, np.newaxis]),
    nu_vac=nu_vac,
)

# --------------------
# Gold reference (Au)
# --------------------
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# --------------------
# Measurement signals
# --------------------
alpha_eff_stack = snompy.fdm.eff_pol_n(
    sample=sample_stack, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_stack = sample_stack.refl_coef(theta_in=theta_in)
sigma_stack = (1 + c_r * r_coef_stack) ** 2 * alpha_eff_stack

alpha_eff_Au = snompy.fdm.eff_pol_n(
    sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
)
r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

# -------------------------------
# Normalized complex scattering
# -------------------------------
eta_n = sigma_stack / sigma_Au

# -----------
# Plotting
# -----------
nu_per_cm = nu_vac * 1e-2

fig, axes = plt.subplots(nrows=2, sharex=True)
axes[0].plot(nu_per_cm, np.abs(eta_n[0]))
axes[1].plot(nu_per_cm, np.angle(eta_n[0]))

axes[0].set_ylabel(r"$s_{" f"{n}" r"}$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_{" f"{n}" r"}$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min()),
)
fig.tight_layout()
plt.show()

# %%
## Combined code for n = 2,3,4 for graphene

# %%
import matplotlib.pyplot as plt
import numpy as np
import snompy

# -----------------------
# Experimental parameters
# -----------------------
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # [m^-1]
method = "Q_ave"

# -------------------------------
# Media: air (superstrate) & Si (substrate)
# -------------------------------
eps_air = 1.0
eps_Si = 11.7

# -------------------------------------------------------
# PMMA dielectric function (synthetic Lorentz model)
# -------------------------------------------------------
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2.0
)
t_pmma = np.array([30e-9])  # 30 nm PMMA

# -------------------------------------------------------
# Graphene monolayer (0.3 nm) via sheet conductivity σ0
# -------------------------------------------------------
eps0 = 8.8541878128e-12
c0   = 299792458.0
e    = 1.602176634e-19
hbar = 1.054571817e-34

sigma0 = e**2 / (4*hbar)
t_g = 0.3e-9

omega = 2*np.pi * c0 * nu_vac
eps_graphene = 1.0 + 1j * sigma0 / (eps0 * omega * t_g)

# -------------------------------
# Demodulation orders
# -------------------------------
demod_orders = [2, 3, 4]
eta_list = []

# -------------------------------
# Calculate eta_n for each n
# -------------------------------
for n in demod_orders:
    sample_stack = snompy.Sample(
        eps_stack=(eps_air, eps_graphene, eps_pmma, eps_Si),
        t_stack=(np.full_like(t_pmma, t_g)[:, np.newaxis],
                 t_pmma[:, np.newaxis]),
        nu_vac=nu_vac,
    )

    # Gold reference
    eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
    sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

    # Stack measurement
    alpha_eff_stack = snompy.fdm.eff_pol_n(
        sample=sample_stack, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
    )
    r_coef_stack = sample_stack.refl_coef(theta_in=theta_in)
    sigma_stack = (1 + c_r * r_coef_stack) ** 2 * alpha_eff_stack

    # Gold measurement
    alpha_eff_Au = snompy.fdm.eff_pol_n(
        sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
    )
    r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
    sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

    # Normalized scattering
    eta_n = sigma_stack / sigma_Au
    eta_list.append(eta_n)

# -------------------------------
# Plotting
# -------------------------------
nu_per_cm = nu_vac * 1e-2
colors = ['tab:blue', 'tab:orange', 'tab:green']

fig, axes = plt.subplots(nrows=2, sharex=True, figsize=(8,5))

for eta, n, c in zip(eta_list, demod_orders, colors):
    axes[0].plot(nu_per_cm, np.abs(eta).flatten(), label=f"n={n}", color=c)
    axes[1].plot(nu_per_cm, np.angle(eta).flatten(), label=f"n={n}", color=c)

axes[0].set_ylabel(r"$|s_n|$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_n$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min())
)

# Legend on the right
axes[0].legend(loc='center left', bbox_to_anchor=(1, 0.5))
axes[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))

fig.tight_layout()

# -------------------------------
# Save figure
# -------------------------------
save_path = r"C:\Users\user\OneDrive\Desktop\Snompy\combined_spectra.png"
fig.savefig(save_path, dpi=300, bbox_inches='tight')
print(f"Figure saved at: {save_path}")

plt.show()
# Out:
# Figure saved at: C:\Users\user\OneDrive\Desktop\Snompy\combined_spectra.png

# %%
## Combine code of PMMA only, Si₃N₄ + PMMA, and Graphene + PMMA n = 2

# %%
import matplotlib.pyplot as plt
import numpy as np
import snompy

# -----------------------
# Experimental parameters
# -----------------------
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
n = 2
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # [m^-1]
method = "Q_ave"

# -----------------------
# Media
# -----------------------
eps_air = 1.0
eps_Si = 11.7

# -----------------------
# PMMA
# -----------------------
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = np.array([30e-9])
sample_P = snompy.Sample(
    eps_stack=(eps_air, eps_pmma, eps_Si),
    t_stack=(t_pmma[:, np.newaxis],),
    nu_vac=nu_vac
)

# -----------------------
# Si3N4 + PMMA
# -----------------------
eps_Si3N4 = snompy.sample.lorentz_perm(
    nu_vac, nu_j=900e2, gamma_j=50e2, A_j=2e8, eps_inf=4.0
)
t_Si3N4 = np.array([15e-9])
sample_Si3N4_P = snompy.Sample(
    eps_stack=(eps_air, eps_Si3N4, eps_pmma, eps_Si),
    t_stack=(t_Si3N4[:, np.newaxis], t_pmma[:, np.newaxis]),
    nu_vac=nu_vac
)

# -----------------------
# Graphene + PMMA
# -----------------------
eps0 = 8.8541878128e-12
c0 = 299792458.0
e = 1.602176634e-19
hbar = 1.054571817e-34

t_g = 0.3e-9
sigma0 = e**2 / (4*hbar)
omega = 2*np.pi * c0 * nu_vac
eps_graphene = 1.0 + 1j * sigma0 / (eps0 * omega * t_g)

t_g_array = np.full_like(t_pmma, t_g)
sample_G_P = snompy.Sample(
    eps_stack=(eps_air, eps_graphene, eps_pmma, eps_Si),
    t_stack=(t_g_array[:, np.newaxis], t_pmma[:, np.newaxis]),
    nu_vac=nu_vac
)

# -----------------------
# Gold reference
# -----------------------
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# -----------------------
# Function to compute normalized scattering
# -----------------------
def compute_eta(sample):
    alpha_eff = snompy.fdm.eff_pol_n(
        sample=sample, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
    )
    r_coef = sample.refl_coef(theta_in=theta_in)
    sigma = (1 + c_r * r_coef) ** 2 * alpha_eff

    alpha_eff_Au = snompy.fdm.eff_pol_n(
        sample=sample_Au, A_tip=A_tip, n=n, r_tip=r_tip, L_tip=L_tip, method=method
    )
    r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
    sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

    return sigma / sigma_Au

# -----------------------
# Compute all etas
# -----------------------
eta_list = [
    compute_eta(sample_P),
    compute_eta(sample_Si3N4_P),
    compute_eta(sample_G_P)
]

labels = [
    f"PMMA {t_pmma[0]*1e9:.0f} nm",
    f"Si3N4 {t_Si3N4[0]*1e9:.0f} nm + PMMA {t_pmma[0]*1e9:.0f} nm",
    f"Graphene {t_g*1e9:.1f} nm + PMMA {t_pmma[0]*1e9:.0f} nm"
]

colors = ['tab:blue', 'tab:orange', 'tab:green']
nu_per_cm = nu_vac * 1e-2

# -----------------------
# Plot
# -----------------------
fig, axes = plt.subplots(nrows=2, sharex=True, figsize=(8,5))

for eta, label, c in zip(eta_list, labels, colors):
    axes[0].plot(nu_per_cm, np.abs(eta[0]), label=label, color=c)
    axes[1].plot(nu_per_cm, np.angle(eta[0]), label=label, color=c)

axes[0].set_ylabel(r"$|s_2|$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi_2$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min())
)

axes[0].legend(loc='center left', bbox_to_anchor=(1, 0.5))  # legend on the right
fig.tight_layout()

# -----------------------
# Save the figure
# -----------------------
fig.savefig(r"C:\Users\user\OneDrive\Desktop\Snompy\snom_spectra.png", dpi=300, bbox_inches='tight')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 import snompy
#       5 # -----------------------
#       6 # Experimental parameters
#       7 # -----------------------
#       8 A_tip = 20e-9
#
# ModuleNotFoundError: No module named 'snompy'

# %%
## Combine code of PMMA only, Si₃N₄ + PMMA, and Graphene + PMMA n = 3

# %%
import matplotlib.pyplot as plt
import numpy as np
import snompy

# -----------------------
# Experimental parameters
# -----------------------
A_tip = 20e-9
r_tip = 200e-9
L_tip = 350e-9
n_list = [2, 2, 2]  # harmonics for each sample
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # [m^-1]
method = "Q_ave"

# -----------------------
# Media
# -----------------------
eps_air = 1.0
eps_Si = 11.7

# -----------------------
# PMMA
# -----------------------
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = np.array([30e-9])  # 1D array

sample_P = snompy.Sample(
    eps_stack=(eps_air, eps_pmma, eps_Si),
    t_stack=(t_pmma[:, np.newaxis],),
    nu_vac=nu_vac
)

# -----------------------
# Si3N4 + PMMA
# -----------------------
eps_Si3N4 = snompy.sample.lorentz_perm(
    nu_vac, nu_j=900e2, gamma_j=50e2, A_j=2e8, eps_inf=4.0
)
t_Si3N4 = np.array([15e-9])

sample_Si3N4_P = snompy.Sample(
    eps_stack=(eps_air, eps_Si3N4, eps_pmma, eps_Si),
    t_stack=(t_Si3N4[:, np.newaxis], t_pmma[:, np.newaxis]),
    nu_vac=nu_vac
)

# -----------------------
# Graphene + PMMA
# -----------------------
eps0 = 8.8541878128e-12
c0 = 299792458.0
e = 1.602176634e-19
hbar = 1.054571817e-34

t_g = 0.3e-9
sigma0 = e**2 / (4*hbar)
omega = 2*np.pi * c0 * nu_vac
eps_graphene = 1.0 + 1j * sigma0 / (eps0 * omega * t_g)

t_g_array = np.full_like(t_pmma, t_g)
sample_G_P = snompy.Sample(
    eps_stack=(eps_air, eps_graphene, eps_pmma, eps_Si),
    t_stack=(t_g_array[:, np.newaxis], t_pmma[:, np.newaxis]),
    nu_vac=nu_vac
)

# -----------------------
# Gold reference
# -----------------------
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# -----------------------
# Function to compute normalized scattering
# -----------------------
def compute_eta(sample):
    alpha_eff = snompy.fdm.eff_pol_n(
        sample=sample, A_tip=A_tip, n=n_list[0], r_tip=r_tip, L_tip=L_tip, method=method
    )
    r_coef = sample.refl_coef(theta_in=theta_in)
    sigma = (1 + c_r * r_coef) ** 2 * alpha_eff

    alpha_eff_Au = snompy.fdm.eff_pol_n(
        sample=sample_Au, A_tip=A_tip, n=n_list[0], r_tip=r_tip, L_tip=L_tip, method=method
    )
    r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
    sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

    return sigma / sigma_Au

# -----------------------
# Compute etas for all samples
# -----------------------
eta_list = [
    compute_eta(sample_P),
    compute_eta(sample_Si3N4_P),
    compute_eta(sample_G_P)
]

labels = [
    f"PMMA {t_pmma[0]*1e9:.0f} nm",
    f"Si3N4 {t_Si3N4[0]*1e9:.0f} nm + PMMA {t_pmma[0]*1e9:.0f} nm",
    f"Graphene {t_g*1e9:.1f} nm + PMMA {t_pmma[0]*1e9:.0f} nm"
]

colors = ['tab:blue', 'tab:orange', 'tab:green']
nu_per_cm = nu_vac * 1e-2

# -----------------------
# Plot
# -----------------------
fig, axes = plt.subplots(nrows=2, sharex=True, figsize=(8,5))

for eta, label, c in zip(eta_list, labels, colors):
    axes[0].plot(nu_per_cm, np.abs(eta[0]), label=label, color=c)
    axes[1].plot(nu_per_cm, np.angle(eta[0]), label=label, color=c)

axes[0].set_ylabel(r"$|s|$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min())
)

axes[0].legend(loc='center left', bbox_to_anchor=(1, 0.5))
fig.tight_layout()

# -----------------------
# Save figure
# -----------------------
#fig.savefig(r"C:\Users\user\OneDrive\Desktop\Snompy\snom_combined.png", dpi=300, bbox_inches='tight')

plt.show()

# %%
## Combine code of PMMA only, Si₃N₄ + PMMA, and Graphene + PMMA n = 4

# %%
import matplotlib.pyplot as plt
import numpy as np
import snompy

# -----------------------
# Experimental parameters
# -----------------------
A_tip = 20e-9
r_tip = 30e-9
L_tip = 350e-9
theta_in = np.deg2rad(60)
c_r = 0.3
nu_vac = np.linspace(1680, 1800, 128) * 1e2  # [m^-1]
method = "Q_ave"

# -----------------------
# Media constants
# -----------------------
eps_air = 1.0
eps_Si = 11.7

# -----------------------
# PMMA (30 nm)
# -----------------------
eps_pmma = snompy.sample.lorentz_perm(
    nu_vac, nu_j=1738e2, gamma_j=20e2, A_j=4.2e8, eps_inf=2
)
t_pmma = np.array([30e-9])

sample_P = snompy.Sample(
    eps_stack=(eps_air, eps_pmma, eps_Si),
    t_stack=(t_pmma[:, np.newaxis],),
    nu_vac=nu_vac
)

# -----------------------
# Si3N4 (15 nm) + PMMA
# -----------------------
eps_Si3N4 = snompy.sample.lorentz_perm(
    nu_vac, nu_j=900e2, gamma_j=50e2, A_j=2e8, eps_inf=4.0
)
t_Si3N4 = np.array([15e-9])

sample_Si3N4_P = snompy.Sample(
    eps_stack=(eps_air, eps_Si3N4, eps_pmma, eps_Si),
    t_stack=(t_Si3N4[:, np.newaxis], t_pmma[:, np.newaxis]),
    nu_vac=nu_vac
)

# -----------------------
# Graphene (0.3 nm) + PMMA
# -----------------------
eps0 = 8.8541878128e-12
c0 = 299792458.0
e = 1.602176634e-19
hbar = 1.054571817e-34

t_g = 0.3e-9
sigma0 = e**2 / (4*hbar)
omega = 2*np.pi * c0 * nu_vac
eps_graphene = 1.0 + 1j * sigma0 / (eps0 * omega * t_g)
t_g_array = np.full_like(t_pmma, t_g)

sample_G_P = snompy.Sample(
    eps_stack=(eps_air, eps_graphene, eps_pmma, eps_Si),
    t_stack=(t_g_array[:, np.newaxis], t_pmma[:, np.newaxis]),
    nu_vac=nu_vac
)

# -----------------------
# Gold reference
# -----------------------
eps_Au = snompy.sample.drude_perm(nu_vac, nu_plasma=7.25e6, gamma=2.16e4)
sample_Au = snompy.bulk_sample(eps_sub=eps_Au, eps_env=eps_air, nu_vac=nu_vac)

# -----------------------
# Function to compute normalized scattering
# -----------------------
def compute_eta(sample, n_harm):
    alpha_eff = snompy.fdm.eff_pol_n(
        sample=sample, A_tip=A_tip, n=n_harm, r_tip=r_tip, L_tip=L_tip, method=method
    )
    r_coef = sample.refl_coef(theta_in=theta_in)
    sigma = (1 + c_r * r_coef) ** 2 * alpha_eff

    alpha_eff_Au = snompy.fdm.eff_pol_n(
        sample=sample_Au, A_tip=A_tip, n=n_harm, r_tip=r_tip, L_tip=L_tip, method=method
    )
    r_coef_Au = sample_Au.refl_coef(theta_in=theta_in)
    sigma_Au = (1 + c_r * r_coef_Au) ** 2 * alpha_eff_Au

    return sigma / sigma_Au

# -----------------------
# Compute etas
# -----------------------
eta_list = [
    compute_eta(sample_P, n_harm=4),
    compute_eta(sample_Si3N4_P, n_harm=4),
    compute_eta(sample_G_P, n_harm=4)
]

labels = [
    f"PMMA {t_pmma[0]*1e9:.0f} nm",
    f"Si3N4 {t_Si3N4[0]*1e9:.0f} nm + PMMA {t_pmma[0]*1e9:.0f} nm",
    f"Graphene {t_g*1e9:.1f} nm + PMMA {t_pmma[0]*1e9:.0f} nm"
]

colors = ['tab:blue', 'tab:orange', 'tab:green']
nu_per_cm = nu_vac * 1e-2

# -----------------------
# Plotting
# -----------------------
fig, axes = plt.subplots(nrows=2, sharex=True, figsize=(8,5))

for eta, label, c in zip(eta_list, labels, colors):
    axes[0].plot(nu_per_cm, np.abs(eta[0]), label=label, color=c)
    axes[1].plot(nu_per_cm, np.angle(eta[0]), label=label, color=c)

axes[0].set_ylabel(r"$|s|$ / a.u.")
axes[1].set(
    xlabel=r"$\nu$ / cm$^{-1}$",
    ylabel=r"$\phi$ / radians",
    xlim=(nu_per_cm.max(), nu_per_cm.min())
)

axes[0].legend(loc='center left', bbox_to_anchor=(1, 0.5))
fig.tight_layout()

# -----------------------
# Save figure
# -----------------------
fig.savefig(r"C:\Users\user\OneDrive\Desktop\Snompy\snom_combined_n4.png", dpi=300, bbox_inches='tight')

plt.show()
